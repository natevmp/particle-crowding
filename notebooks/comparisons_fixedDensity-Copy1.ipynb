# %% [markdown]
# # Particle simulation vs Langevin model

# %%
using Revise

# %%
include("../src/bmparticles.jl")
include("../src/bmtheory.jl")
using .BParts
using .Theorist

# %%
using DifferentialEquations, Distributions, LaTeXStrings, ProgressMeter

# %%
# using Plots
# # plotly()
# gr()

# %% [markdown]
# ## Fixed Density
#
# First we compare the particle simulation with the simulations of the Langevin equation (and some analytical results from it) for a fixed population size.
#
# When comparing the two we must take care to ensure both approaches are modeling the same system. In particular, a particle modeled by the Langevin equation has its future speed distribution initially determined by the energy of the system, as it is parameterized by $D/\gamma$ (see equation (3) in document) which can be equated to the average energy per particle $\left< E \right>$ (4); however in the simulation particles are introduced into the system with a speed rather than an energy. If the simulation is initiated with all particles having the same speed -- which is convenient to ensure the system evolves to the predetermined equilibrium, as opposed to drawing their speeds from the desired distribution in which case the system energy becomes a random variable -- we must ensure the average energy matches that of the Langevin particle. We know that
# \begin{equation}
#     \left< E \right> = \frac{\left< v^2 \right>}{2}
# \end{equation}
# thus using $\left< v_0^2 \right> = \left< s_0^2 \right> = s_0^2$ (since all particles have the same speed initially) we know that the initial particle speed and the average energy per particle are related through
# \begin{align}
#     s_0 = \sqrt{2\left< E \right>} \\
#     \left< E \right> = \frac{s_0^2}{2}
# \end{align}
# Note that as the system evolves the particle speeds should become distributed according to the Rayleigh distribution, and the average speed becomes
# \begin{equation}
#     \left< s \right> = \sqrt{E} \sqrt{\frac{\pi}{2}}
# \end{equation}

# %% [markdown]
# ### Parameters for simulation

# %%
function extendParams!(arenaParams::Dict)
    bounds = arenaParams["bounds"]
    arenaParams["volume"] = abs(bounds[1][2]-bounds[1][1])*abs(bounds[2][2]-bounds[2][1])
    arenaParams["bperiod"] = [abs(bounds[1][2]-bounds[1][1]), abs(bounds[2][2]-bounds[2][1])]
end
# Out:
# extendParams! (generic function with 1 method)

# %%
arenaParams = 
    Dict(
        "n0"=>400,
        "evolveTime"=>3000,
        "timeStep"=> 0.05,
        "bounds"=>((0.,5.),(0.,5.)), 
        "radius"=>0.08, 
        "speed"=>0.02
    )

extendParams!(arenaParams)
for p in arenaParams
    println(p)
end

waitTime = 1500
timeSteps = arenaParams["timeStep"]:arenaParams["timeStep"]:arenaParams["evolveTime"]

display(arenaParams)

function fillDensity(arenaParams)  
    xperiod = abs(arenaParams["bounds"][1][2] - arenaParams["bounds"][1][1])
    yperiod = abs(arenaParams["bounds"][2][2] - arenaParams["bounds"][2][1])
    n0 = arenaParams["n0"]
    r = arenaParams["radius"]
    V = xperiod*yperiod
    fillDens = n0*π*r^2 / V
    return fillDens
end

println("surface covered: ", fillDensity(arenaParams))
# Out:
# Pair{String,Any}("volume", 25.0)
# Pair{String,Any}("evolveTime", 3000)
# Pair{String,Any}("speed", 0.02)
# Pair{String,Any}("radius", 0.08)
# Pair{String,Any}("timeStep", 0.05)
# Pair{String,Any}("bounds", ((0.0, 5.0), (0.0, 5.0)))
# Pair{String,Any}("bperiod",
# Dict{String,Any} with 8 entries:
#   "volume"     => 25.0
#   "evolveTime" => 3000
#   "speed"      => 0.02
#   "radius"     => 0.08
#   "timeStep"   => 0.05
#   "bounds"     => ((0.0, 5.0), (0.0, 5.0))
#   "bperiod"    => [5.0, 5.0]
#   "n0"         => 400
# [5.0, 5.0])
# Pair{String,Any}("n0", 400)
# surface covered: 0.32169908772759487

# %%
thermVals = Theorist.thermalValues(arenaParams)
# Out:
# Dict{Any,Any} with 7 entries:
#   "γ"  => 0.128339
#   "ρ"  => 0.321699
#   "σc" => 0.32
#   "D"  => 2.56679e-5
#   "l"  => 0.138107
#   "E"  => 0.0002
#   "n"  => 16.0

# %% [markdown]
# ### Simulations

# %% [markdown]
# run a particle simulation:

# %%
succes = false
while !succes 
    # try/catch construction in case boundserror occurs
    try
        arena, pos_t_dim_id, vel_t_dim_id, cells_T_ID = 
            BParts.randArenaEvolve(arenaParams["n0"], arenaParams["evolveTime"], arenaParams["timeStep"], arenaParams; 
                verbose=true, overlapScans=200, attempts = 100)

        println("energy per cell: ",
                BParts.kineticEnergy(arena) / arenaParams["n0"]
            )
    catch e
        println("fail")
        continue 
    end
    succes = true
end
# Out:
# Building arena...
# 304 overlaps fixed. Making another pass...
# 1
# 200
# 186 overlaps fixed. Making another pass...
# 2
# 200
# 157 overlaps fixed. Making another pass...
# 3
# 200
# 154 overlaps fixed. Making another pass...
# 4
# 200
# 131 overlaps fixed. Making another pass...
# 5
# 200
# 136 overlaps fixed. Making another pass...
# 6
# 200
# 106 overlaps fixed. Making another pass...
# 7
# 200
# 172 overlaps fixed. Making another pass...
# 8
# 200
# 121 overlaps fixed. Making another pass...
# 9
# 200
# 141 overlaps fixed. Making another pass...
# 10
# 200
# 145 overlaps fixed. Making another pass...
# 11
# 200
# 136 overlaps fixed. Making another pass...
# 12
# 200
# 114 overlaps fixed. Making another pass...
# 13
# 200
# 131 overlaps fixed. Making another pass...
# 14
# 200
# 157 overlaps fixed. Making another pass...
# 15
# 200
# 147 overlaps fixed. Making another pass...
# 16
# 200
# 104 overlaps fixed. Making another pass...
# 17
# 200
# 107 overlaps fixed. Making another pass...
# 18
# 200
# 111 overlaps fixed. Making another pass...
# 19
# 200
# 134 overlaps fixed. Making another pass...
# 20
# 200
# 100 overlaps fixed. Making another pass...
# 21
# 200
# 117 overlaps fixed. Making another pass...
# 22
# 200
# 93 overlaps fixed. Making another pass...
# 23
# 200
# 130 overlaps fixed. Making another pass...
# 24
# 200
# 119 overlaps fixed. Making another pass...
# 25
# 200
# 114 overlaps fixed. Making another pass...
# 26
# 200
# 101 overlaps fixed. Making another pass...
# 27
# 200
# 119 overlaps fixed. Making another pass...
# 28
# 200
# 100 overlaps fixed. Making another pass...
# 29
# 200
# 124 overlaps fixed. Making another pass...
# 30
# 200
# 103 overlaps fixed. Making another pass...
# 31
# 200
# 127 overlaps fixed. Making another pass...
# 32
# 200
# 120 overlaps fixed. Making another pass...
# 33
# 200
# 112 overlaps fixed. Making another pass...
# 34
# 200
# 96 overlaps fixed. Making another pass...
# 35
# 200
# 117 overlaps fixed. Making another pass...
# 36
# 200
# 128 overlaps fixed. Making another pass...
# 37
# 200
# 116 overlaps fixed. Making another pass...
# 38
# 200
# 142 overlaps fixed. Making another pass...
# 39
# 200
# 131 overlaps fixed. Making another pass...
# 40
# 200
# 113 overlaps fixed. Making another pass...
# 41
# 200
# 108 overlaps fixed. Making another pass...
# 42
# 200
# 112 overlaps fixed. Making another pass...
# 43
# 200
# 106 overlaps fixed. Making another pass...
# 44
# 200
# 95 overlaps fixed. Making another pass...
# 45
# 200
# 110 overlaps fixed. Making another pass...
# 46
# 200
# 105 overlaps fixed. Making another pass...
# 47
# 200
# 120 overlaps fixed. Making another pass...
# 48
# 200
# 130 overlaps fixed. Making another pass...
# 49
# 200
# 105 overlaps fixed. Making another pass...
# 50
# 200
# 119 overlaps fixed. Making another pass...
# 51
# 200
# 97 overlaps fixed. Making another pass...
# 52
# 200
# 100 overlaps fixed. Making another pass...
# 53
# 200
# 101 overlaps fixed. Making another pass...
# 54
# 200
# 139 overlaps fixed. Making another pass...
# 55
# 200
# 127 overlaps fixed. Making another pass...
# 56
# 200
# 124 overlaps fixed. Making another pass...
# 57
# 200
# 91 overlaps fixed. Making another pass...
# 58
# 200
# 112 overlaps fixed. Making another pass...
# 59
# 200
# 92 overlaps fixed. Making another pass...
# 60
# 200
# 111 overlaps fixed. Making another pass...
# 61
# 200
# 92 overlaps fixed. Making another pass...
# 62
# 200
# 111 overlaps fixed. Making another pass...
# 63
# 200
# 88 overlaps fixed. Making another pass...
# 64
# 200
# 119 overlaps fixed. Making another pass...
# 65
# 200
# 101 overlaps fixed. Making another pass...
# 66
# 200
# 122 overlaps fixed. Making another pass...
# 67
# 200
# 100 overlaps fixed. Making another pass...
# 68
# 200
# 96 overlaps fixed. Making another pass...
# 69
# 200
# 109 overlaps fixed. Making another pass...
# 70
# 200
# 88 overlaps fixed. Making another pass...
# 71
# 200
# 93 overlaps fixed. Making another pass...
# 72
# 200
# 94 overlaps fixed. Making another pass...
# 73
# 200
# 107 overlaps fixed. Making another pass...
# 74
# 200
# 91 overlaps fixed. Making another pass...
# 75
# 200
# 94 overlaps fixed. Making another pass...
# 76
# 200
# 70 overlaps fixed. Making another pass...
# 77
# 200
# 90 overlaps fixed. Making another pass...
# 78
# 200
# 95 overlaps fixed. Making another pass...
# 79
# 200
# 110 overlaps fixed. Making another pass...
# 80
# 200
# 117 overlaps fixed. Making another pass...
# 81
# 200
# 122 overlaps fixed. Making another pass...
# 82
# 200
# 83 overlaps fixed. Making another pass...
# 83
# 200
# 91 overlaps fixed. Making another pass...
# 84
# 200
# 73 overlaps fixed. Making another pass...
# 85
# 200
# 90 overlaps fixed. Making another pass...
# 86
# 200
# 91 overlaps fixed. Making another pass...
# 87
# 200
# 80 overlaps fixed. Making another pass...
# 88
# 200
# 69 overlaps fixed. Making another pass...
# 89
# 200
# 67 overlaps fixed. Making another pass...
# 90
# 200
# 95 overlaps fixed. Making another pass...
# 91
# 200
# 115 overlaps fixed. Making another pass...
# 92
# 200
# 104 overlaps fixed. Making another pass...
# 93
# 200
# 109 overlaps fixed. Making another pass...
# 94
# 200
# 112 overlaps fixed. Making another pass...
# 95
# 200
# 104 overlaps fixed. Making another pass...
# 96
# 200
# 110 overlaps fixed. Making another pass...
# 97
# 200
# 150 overlaps fixed. Making another pass...
# 98
# 200
# 139 overlaps fixed. Making another pass...
# 99
# 200
# 157 overlaps fixed. Making another pass...
# 100
# 200
# 119 overlaps fixed. Making another pass...
# 101
# 200
# 137 overlaps fixed. Making another pass...
# 102
# 200
# 121 overlaps fixed. Making another pass...
# 103
# 200
# 156 overlaps fixed. Making another pass...
# 104
# 200
# 98 overlaps fixed. Making another pass...
# 105
# 200
# 83 overlaps fixed. Making another pass...
# 106
# 200
# 89 overlaps fixed. Making another pass...
# 107
# 200
# 109 overlaps fixed. Making another pass...
# 108
# 200
# 90 overlaps fixed. Making another pass...
# 109
# 200
# 126 overlaps fixed. Making another pass...
# 110
# 200
# 82 overlaps fixed. Making another pass...
# 111
# 200
# 121 overlaps fixed. Making another pass...
# 112
# 200
# 105 overlaps fixed. Making another pass...
# 113
# 200
# 116 overlaps fixed. Making another pass...
# 114
# 200
# 119 overlaps fixed. Making another pass...
# 115
# 200
# 109 overlaps fixed. Making another pass...
# 116
# 200
# 134 overlaps fixed. Making another pass...
# 117
# 200
# 155 overlaps fixed. Making another pass...
# 118
# 200
# 140 overlaps fixed. Making another pass...
# 119
# 200
# 126 overlaps fixed. Making another pass...
# 120
# 200
# 148 overlaps fixed. Making another pass...
# 121
# 200
# 143 overlaps fixed. Making another pass...
# 122
# 200
# 153 overlaps fixed. Making another pass...
# 123
# 200
# 97 overlaps fixed. Making another pass...
# 124
# 200
# 122 overlaps fixed. Making another pass...
# 125
# 200
# 125 overlaps fixed. Making another pass...
# 126
# 200
# 138 overlaps fixed. Making another pass...
# 127
# 200
# 107 overlaps fixed. Making another pass...
# 128
# 200
# 103 overlaps fixed. Making another pass...
# 129
# 200
# 154 overlaps fixed. Making another pass...
# 130
# 200
# 119 overlaps fixed. Making another pass...
# 131
# 200
# 118 overlaps fixed. Making another pass...
# 132
# 200
# 124 overlaps fixed. Making another pass...
# 133
# 200
# 118 overlaps fixed. Making another pass...
# 134
# 200
# 164 overlaps fixed. Making another pass...
# 135
# 200
# 175 overlaps fixed. Making another pass...
# 136
# 200
# 113 overlaps fixed. Making another pass...
# 137
# 200
# 131 overlaps fixed. Making another pass...
# 138
# 200
# 149 overlaps fixed. Making another pass...
# 139
# 200
# 109 overlaps fixed. Making another pass...
# 140
# 200
# 118 overlaps fixed. Making another pass...
# 141
# 200
# 112 overlaps fixed. Making another pass...
# 142
# 200
# 101 overlaps fixed. Making another pass...
# 143
# 200
# 95 overlaps fixed. Making another pass...
# 144
# 200
# 122 overlaps fixed. Making another pass...
# 145
# 200
# 111 overlaps fixed. Making another pass...
# 146
# 200
# 140 overlaps fixed. Making another pass...
# 147
# 200
# 118 overlaps fixed. Making another pass...
# 148
# 200
# 103 overlaps fixed. Making another pass...
# 149
# 200
# 104 overlaps fixed. Making another pass...
# 150
# 200
# 109 overlaps fixed. Making another pass...
# 151
# 200
# 95 overlaps fixed. Making another pass...
# 152
# 200
# 111 overlaps fixed. Making another pass...
# 153
# 200
# 85 overlaps fixed. Making another pass...
# 154
# 200
# 108 overlaps fixed. Making another pass...
# 155
# 200
# 158 overlaps fixed. Making another pass...
# 156
# 200
# 123 overlaps fixed. Making another pass...
# 157
# 200
# 113 overlaps fixed. Making another pass...
# 158
# 200
# 123 overlaps fixed. Making another pass...
# 159
# 200
# 92 overlaps fixed. Making another pass...
# 160
# 200
# 99 overlaps fixed. Making another pass...
# 161
# 200
# 88 overlaps fixed. Making another pass...
# 162
# 200
# 119 overlaps fixed. Making another pass...
# 163
# 200
# 94 overlaps fixed. Making another pass...
# 164
# 200
# 78 overlaps fixed. Making another pass...
# 165
# 200
# 90 overlaps fixed. Making another pass...
# 166
# 200
# 112 overlaps fixed. Making another pass...
# 167
# 200
# 99 overlaps fixed. Making another pass...
# 168
# 200
# 86 overlaps fixed. Making another pass...
# 169
# 200
# 93 overlaps fixed. Making another pass...
# 170
# 200
# 93 overlaps fixed. Making another pass...
# 171
# 200
# 97 overlaps fixed. Making another pass...
# 172
# 200
# 105 overlaps fixed. Making another pass...
# 173
# 200
# 115 overlaps fixed. Making another pass...
# 174
# 200
# 92 overlaps fixed. Making another pass...
# 175
# 200
# 88 overlaps fixed. Making another pass...
# 176
# 200
# 82 overlaps fixed. Making another pass...
# 177
# 200
# 79 overlaps fixed. Making another pass...
# 178
# 200
# 107 overlaps fixed. Making another pass...
# 179
# 200
# 125 overlaps fixed. Making another pass...
# 180
# 200
# 106 overlaps fixed. Making another pass...
# 181
# 200
# 121 overlaps fixed. Making another pass...
# 182
# 200
# 124 overlaps fixed. Making another pass...
# 183
# 200
# 134 overlaps fixed. Making another pass...
# 184
# 200
# 109 overlaps fixed. Making another pass...
# 185
# 200
# 112 overlaps fixed. Making another pass...
# 186
# 200
# 127 overlaps fixed. Making another pass...
# 187
# 200
# 121 overlaps fixed. Making another pass...
# 188
# 200
# 129 overlaps fixed. Making another pass...
# 189
# 200
# 108 overlaps fixed. Making another pass...
# 190
# 200
# 136 overlaps fixed. Making another pass...
# 191
# 200
# 132 overlaps fixed. Making another pass...
# 192
# 200
# 140 overlaps fixed. Making another pass...
# 193
# 200
# 98 overlaps fixed. Making another pass...
# 194
# 200
# 89 overlaps fixed. Making another pass...
# 195
# 200
# 153 overlaps fixed. Making another pass...
# 196
# 200
# 102 overlaps fixed. Making another pass...
# 197
# 200
# 109 overlaps fixed. Making another pass...
# 198
# 200
# 65 overlaps fixed. Making another pass...
# 199
# 200
# 118 overlaps fixed. Making another pass...
# 200
# 200
# 73 overlaps fixed. Making another pass...
# 201
# 200
# 282 overlaps fixed. Making another pass...
# 1
# 200
# 211 overlaps fixed. Making another pass...
# 2
# 200
# 183 overlaps fixed. Making another pass...
# 3
# 200
# 143 overlaps fixed. Making another pass...
# 4
# 200
# 155 overlaps fixed. Making another pass...
# 5
# 200
# 123 overlaps fixed. Making another pass...
# 6
# 200
# 129 overlaps fixed. Making another pass...
# 7
# 200
# 94 overlaps fixed. Making another pass...
# 8
# 200
# 133 overlaps fixed. Making another pass...
# 9
# 200
# 93 overlaps fixed. Making another pass...
# 10
# 200
# 74 overlaps fixed. Making another pass...
# 11
# 200
# 76 overlaps fixed. Making another pass...
# 12
# 200
# 72 overlaps fixed. Making another pass...
# 13
# 200
# 82 overlaps fixed. Making another pass...
# 14
# 200
# 92 overlaps fixed. Making another pass...
# 15
# 200
# 76 overlaps fixed. Making another pass...
# 16
# 200
# 81 overlaps fixed. Making another pass...
# 17
# 200
# 94 overlaps fixed. Making another pass...
# 18
# 200
# 85 overlaps fixed. Making another pass...
# 19
# 200
# 108 overlaps fixed. Making another pass...
# 20
# 200
# 106 overlaps fixed. Making another pass...
# 21
# 200
# 91 overlaps fixed. Making another pass...
# 22
# 200
# 93 overlaps fixed. Making another pass...
# 23
# 200
# 112 overlaps fixed. Making another pass...
# 24
# 200
# 89 overlaps fixed. Making another pass...
# 25
# 200
# 126 overlaps fixed. Making another pass...
# 26
# 200
# 89 overlaps fixed. Making another pass...
# 27
# 200
# 99 overlaps fixed. Making another pass...
# 28
# 200
# 101 overlaps fixed. Making another pass...
# 29
# 200
# 100 overlaps fixed. Making another pass...
# 30
# 200
# 110 overlaps fixed. Making another pass...
# 31
# 200
# 107 overlaps fixed. Making another pass...
# 32
# 200
# 107 overlaps fixed. Making another pass...
# 33
# 200
# 109 overlaps fixed. Making another pass...
# 34
# 200
# 126 overlaps fixed. Making another pass...
# 35
# 200
# 104 overlaps fixed. Making another pass...
# 36
# 200
# 117 overlaps fixed. Making another pass...
# 37
# 200
# 105 overlaps fixed. Making another pass...
# 38
# 200
# 86 overlaps fixed. Making another pass...
# 39
# 200
# 118 overlaps fixed. Making another pass...
# 40
# 200
# 112 overlaps fixed. Making another pass...
# 41
# 200
# 109 overlaps fixed. Making another pass...
# 42
# 200
# 88 overlaps fixed. Making another pass...
# 43
# 200
# 132 overlaps fixed. Making another pass...
# 44
# 200
# 133 overlaps fixed. Making another pass...
# 45
# 200
# 91 overlaps fixed. Making another pass...
# 46
# 200
# 116 overlaps fixed. Making another pass...
# 47
# 200
# 142 overlaps fixed. Making another pass...
# 48
# 200
# 111 overlaps fixed. Making another pass...
# 49
# 200
# 160 overlaps fixed. Making another pass...
# 50
# 200
# 127 overlaps fixed. Making another pass...
# 51
# 200
# 92 overlaps fixed. Making another pass...
# 52
# 200
# 110 overlaps fixed. Making another pass...
# 53
# 200
# 122 overlaps fixed. Making another pass...
# 54
# 200
# 111 overlaps fixed. Making another pass...
# 55
# 200
# 104 overlaps fixed. Making another pass...
# 56
# 200
# 106 overlaps fixed. Making another pass...
# 57
# 200
# 96 overlaps fixed. Making another pass...
# 58
# 200
# 88 overlaps fixed. Making another pass...
# 59
# 200
# 96 overlaps fixed. Making another pass...
# 60
# 200
# 101 overlaps fixed. Making another pass...
# 61
# 200
# 115 overlaps fixed. Making another pass...
# 62
# 200
# 100 overlaps fixed. Making another pass...
# 63
# 200
# 93 overlaps fixed. Making another pass...
# 64
# 200
# 116 overlaps fixed. Making another pass...
# 65
# 200
# 111 overlaps fixed. Making another pass...
# 66
# 200
# 153 overlaps fixed. Making another pass...
# 67
# 200
# 116 overlaps fixed. Making another pass...
# 68
# 200
# 139 overlaps fixed. Making another pass...
# 69
# 200
# 105 overlaps fixed. Making another pass...
# 70
# 200
# 138 overlaps fixed. Making another pass...
# 71
# 200
# 119 overlaps fixed. Making another pass...
# 72
# 200
# 124 overlaps fixed. Making another pass...
# 73
# 200
# 112 overlaps fixed. Making another pass...
# 74
# 200
# 109 overlaps fixed. Making another pass...
# 75
# 200
# 107 overlaps fixed. Making another pass...
# 76
# 200
# 129 overlaps fixed. Making another pass...
# 77
# 200
# 108 overlaps fixed. Making another pass...
# 78
# 200
# 111 overlaps fixed. Making another pass...
# 79
# 200
# 98 overlaps fixed. Making another pass...
# 80
# 200
# 102 overlaps fixed. Making another pass...
# 81
# 200
# 99 overlaps fixed. Making another pass...
# 82
# 200
# 127 overlaps fixed. Making another pass...
# 83
# 200
# 124 overlaps fixed. Making another pass...
# 84
# 200
# 94 overlaps fixed. Making another pass...
# 85
# 200
# 123 overlaps fixed. Making another pass...
# 86
# 200
# 98 overlaps fixed. Making another pass...
# 87
# 200
# 108 overlaps fixed. Making another pass...
# 88
# 200
# 94 overlaps fixed. Making another pass...
# 89
# 200
# 144 overlaps fixed. Making another pass...
# 90
# 200
# 109 overlaps fixed. Making another pass...
# 91
# 200
# 126 overlaps fixed. Making another pass...
# 92
# 200
# 108 overlaps fixed. Making another pass...
# 93
# 200
# 104 overlaps fixed. Making another pass...
# 94
# 200
# 129 overlaps fixed. Making another pass...
# 95
# 200
# 126 overlaps fixed. Making another pass...
# 96
# 200
# 108 overlaps fixed. Making another pass...
# 97
# 200
# 102 overlaps fixed. Making another pass...
# 98
# 200
# 97 overlaps fixed. Making another pass...
# 99
# 200
# 110 overlaps fixed. Making another pass...
# 100
# 200
# 125 overlaps fixed. Making another pass...
# 101
# 200
# 140 overlaps fixed. Making another pass...
# 102
# 200
# 122 overlaps fixed. Making another pass...
# 103
# 200
# 104 overlaps fixed. Making another pass...
# 104
# 200
# 121 overlaps fixed. Making another pass...
# 105
# 200
# 123 overlaps fixed. Making another pass...
# 106
# 200
# 124 overlaps fixed. Making another pass...
# 107
# 200
# 122 overlaps fixed. Making another pass...
# 108
# 200
# 116 overlaps fixed. Making another pass...
# 109
# 200
# 131 overlaps fixed. Making another pass...
# 110
# 200
# 109 overlaps fixed. Making another pass...
# 111
# 200
# 95 overlaps fixed. Making another pass...
# 112
# 200
# 142 overlaps fixed. Making another pass...
# 113
# 200
# 97 overlaps fixed. Making another pass...
# 114
# 200
# 99 overlaps fixed. Making another pass...
# 115
# 200
# 96 overlaps fixed. Making another pass...
# 116
# 200
# 103 overlaps fixed. Making another pass...
# 117
# 200
# 104 overlaps fixed. Making another pass...
# 118
# 200
# 103 overlaps fixed. Making another pass...
# 119
# 200
# 103 overlaps fixed. Making another pass...
# 120
# 200
# 109 overlaps fixed. Making another pass...
# 121
# 200
# 84 overlaps fixed. Making another pass...
# 122
# 200
# 118 overlaps fixed. Making another pass...
# 123
# 200
# 107 overlaps fixed. Making another pass...
# 124
# 200
# 122 overlaps fixed. Making another pass...
# 125
# 200
# 134 overlaps fixed. Making another pass...
# 126
# 200
# 97 overlaps fixed. Making another pass...
# 127
# 200
# 92 overlaps fixed. Making another pass...
# 128
# 200
# 114 overlaps fixed. Making another pass...
# 129
# 200
# 103 overlaps fixed. Making another pass...
# 130
# 200
# 107 overlaps fixed. Making another pass...
# 131
# 200
# 116 overlaps fixed. Making another pass...
# 132
# 200
# 108 overlaps fixed. Making another pass...
# 133
# 200
# 124 overlaps fixed. Making another pass...
# 134
# 200
# 122 overlaps fixed. Making another pass...
# 135
# 200
# 107 overlaps fixed. Making another pass...
# 136
# 200
# 95 overlaps fixed. Making another pass...
# 137
# 200
# 107 overlaps fixed. Making another pass...
# 138
# 200
# 119 overlaps fixed. Making another pass...
# 139
# 200
# 123 overlaps fixed. Making another pass...
# 140
# 200
# 119 overlaps fixed. Making another pass...
# 141
# 200
# 90 overlaps fixed. Making another pass...
# 142
# 200
# 90 overlaps fixed. Making another pass...
# 143
# 200
# 108 overlaps fixed. Making another pass...
# 144
# 200
# 138 overlaps fixed. Making another pass...
# 145
# 200
# 90 overlaps fixed. Making another pass...
# 146
# 200
# 91 overlaps fixed. Making another pass...
# 147
# 200
# 122 overlaps fixed. Making another pass...
# 148
# 200
# 103 overlaps fixed. Making another pass...
# 149
# 200
# 95 overlaps fixed. Making another pass...
# 150
# 200
# 117 overlaps fixed. Making another pass...
# 151
# 200
# 106 overlaps fixed. Making another pass...
# 152
# 200
# 92 overlaps fixed. Making another pass...
# 153
# 200
# 125 overlaps fixed. Making another pass...
# 154
# 200
# 100 overlaps fixed. Making another pass...
# 155
# 200
# 121 overlaps fixed. Making another pass...
# 156
# 200
# 109 overlaps fixed. Making another pass...
# 157
# 200
# 135 overlaps fixed. Making another pass...
# 158
# 200
# 115 overlaps fixed. Making another pass...
# 159
# 200
# 103 overlaps fixed. Making another pass...
# 160
# 200
# 92 overlaps fixed. Making another pass...
# 161
# 200
# 108 overlaps fixed. Making another pass...
# 162
# 200
# 109 overlaps fixed. Making another pass...
# 163
# 200
# 97 overlaps fixed. Making another pass...
# 164
# 200
# 118 overlaps fixed. Making another pass...
# 165
# 200
# 119 overlaps fixed. Making another pass...
# 166
# 200
# 144 overlaps fixed. Making another pass...
# 167
# 200
# 119 overlaps fixed. Making another pass...
# 168
# 200
# 131 overlaps fixed. Making another pass...
# 169
# 200
# 125 overlaps fixed. Making another pass...
# 170
# 200
# 79 overlaps fixed. Making another pass...
# 171
# 200
# 131 overlaps fixed. Making another pass...
# 172
# 200
# 109 overlaps fixed. Making another pass...
# 173
# 200
# 118 overlaps fixed. Making another pass...
# 174
# 200
# 96 overlaps fixed. Making another pass...
# 175
# 200
# 111 overlaps fixed. Making another pass...
# 176
# 200
# 117 overlaps fixed. Making another pass...
# 177
# 200
# 129 overlaps fixed. Making another pass...
# 178
# 200
# 143 overlaps fixed. Making another pass...
# 179
# 200
# 130 overlaps fixed. Making another pass...
# 180
# 200
# 105 overlaps fixed. Making another pass...
# 181
# 200
# 106 overlaps fixed. Making another pass...
# 182
# 200
# 131 overlaps fixed. Making another pass...
# 183
# 200
# 124 overlaps fixed. Making another pass...
# 184
# 200
# 106 overlaps fixed. Making another pass...
# 185
# 200
# 124 overlaps fixed. Making another pass...
# 186
# 200
# 122 overlaps fixed. Making another pass...
# 187
# 200
# 145 overlaps fixed. Making another pass...
# 188
# 200
# 120 overlaps fixed. Making another pass...
# 189
# 200
# 182 overlaps fixed. Making another pass...
# 190
# 200
# 127 overlaps fixed. Making another pass...
# 191
# 200
# 122 overlaps fixed. Making another pass...
# 192
# 200
# 107 overlaps fixed. Making another pass...
# 193
# 200
# 106 overlaps fixed. Making another pass...
# 194
# 200
# 97 overlaps fixed. Making another pass...
# 195
# 200
# 87 overlaps fixed. Making another pass...
# 196
# 200
# 80 overlaps fixed. Making another pass...
# 197
# 200
# 99 overlaps fixed. Making another pass...
# 198
# 200
# 110 overlaps fixed. Making another pass...
# 199
# 200
# 112 overlaps fixed. Making another pass...
# 200
# 200
# 129 overlaps fixed. Making another pass...
# 201
# 200
# 293 overlaps fixed. Making another pass...
# 1
# 200
# 184 overlaps fixed. Making another pass...
# 2
# 200
# 168 overlaps fixed. Making another pass...
# 3
# 200
# 142 overlaps fixed. Making another pass...
# 4
# 200
# 138 overlaps fixed. Making another pass...
# 5
# 200
# 133 overlaps fixed. Making another pass...
# 6
# 200
# 106 overlaps fixed. Making another pass...
# 7
# 200
# 134 overlaps fixed. Making another pass...
# 8
# 200
# 123 overlaps fixed. Making another pass...
# 9
# 200
# 116 overlaps fixed. Making another pass...
# 10
# 200
# 139 overlaps fixed. Making another pass...
# 11
# 200
# 111 overlaps fixed. Making another pass...
# 12
# 200
# 107 overlaps fixed. Making another pass...
# 13
# 200
# 79 overlaps fixed. Making another pass...
# 14
# 200
# 101 overlaps fixed. Making another pass...
# 15
# 200
# 123 overlaps fixed. Making another pass...
# 16
# 200
# 92 overlaps fixed. Making another pass...
# 17
# 200
# 106 overlaps fixed. Making another pass...
# 18
# 200
# 107 overlaps fixed. Making another pass...
# 19
# 200
# 90 overlaps fixed. Making another pass...
# 20
# 200
# 106 overlaps fixed. Making another pass...
# 21
# 200
# 122 overlaps fixed. Making another pass...
# 22
# 200
# 106 overlaps fixed. Making another pass...
# 23
# 200
# 119 overlaps fixed. Making another pass...
# 24
# 200
# 130 overlaps fixed. Making another pass...
# 25
# 200
# 136 overlaps fixed. Making another pass...
# 26
# 200
# 95 overlaps fixed. Making another pass...
# 27
# 200
# 100 overlaps fixed. Making another pass...
# 28
# 200
# 110 overlaps fixed. Making another pass...
# 29
# 200
# 101 overlaps fixed. Making another pass...
# 30
# 200
# 155 overlaps fixed. Making another pass...
# 31
# 200
# 165 overlaps fixed. Making another pass...
# 32
# 200
# 111 overlaps fixed. Making another pass...
# 33
# 200
# 102 overlaps fixed. Making another pass...
# 34
# 200
# 109 overlaps fixed. Making another pass...
# 35
# 200
# 115 overlaps fixed. Making another pass...
# 36
# 200
# 132 overlaps fixed. Making another pass...
# 37
# 200
# 98 overlaps fixed. Making another pass...
# 38
# 200
# 94 overlaps fixed. Making another pass...
# 39
# 200
# 112 overlaps fixed. Making another pass...
# 40
# 200
# 132 overlaps fixed. Making another pass...
# 41
# 200
# 98 overlaps fixed. Making another pass...
# 42
# 200
# 100 overlaps fixed. Making another pass...
# 43
# 200
# 74 overlaps fixed. Making another pass...
# 44
# 200
# 84 overlaps fixed. Making another pass...
# 45
# 200
# 89 overlaps fixed. Making another pass...
# 46
# 200
# 101 overlaps fixed. Making another pass...
# 47
# 200
# 86 overlaps fixed. Making another pass...
# 48
# 200
# 87 overlaps fixed. Making another pass...
# 49
# 200
# 120 overlaps fixed. Making another pass...
# 50
# 200
# 96 overlaps fixed. Making another pass...
# 51
# 200
# 98 overlaps fixed. Making another pass...
# 52
# 200
# 118 overlaps fixed. Making another pass...
# 53
# 200
# 124 overlaps fixed. Making another pass...
# 54
# 200
# 120 overlaps fixed. Making another pass...
# 55
# 200
# 93 overlaps fixed. Making another pass...
# 56
# 200
# 148 overlaps fixed. Making another pass...
# 57
# 200
# 112 overlaps fixed. Making another pass...
# 58
# 200
# 136 overlaps fixed. Making another pass...
# 59
# 200
# 123 overlaps fixed. Making another pass...
# 60
# 200
# 100 overlaps fixed. Making another pass...
# 61
# 200
# 138 overlaps fixed. Making another pass...
# 62
# 200
# 106 overlaps fixed. Making another pass...
# 63
# 200
# 121 overlaps fixed. Making another pass...
# 64
# 200
# 112 overlaps fixed. Making another pass...
# 65
# 200
# 139 overlaps fixed. Making another pass...
# 66
# 200
# 91 overlaps fixed. Making another pass...
# 67
# 200
# 75 overlaps fixed. Making another pass...
# 68
# 200
# 83 overlaps fixed. Making another pass...
# 69
# 200
# 114 overlaps fixed. Making another pass...
# 70
# 200
# 104 overlaps fixed. Making another pass...
# 71
# 200
# 102 overlaps fixed. Making another pass...
# 72
# 200
# 125 overlaps fixed. Making another pass...
# 73
# 200
# 110 overlaps fixed. Making another pass...
# 74
# 200
# 80 overlaps fixed. Making another pass...
# 75
# 200
# 108 overlaps fixed. Making another pass...
# 76
# 200
# 103 overlaps fixed. Making another pass...
# 77
# 200
# 146 overlaps fixed. Making another pass...
# 78
# 200
# 128 overlaps fixed. Making another pass...
# 79
# 200
# 107 overlaps fixed. Making another pass...
# 80
# 200
# 137 overlaps fixed. Making another pass...
# 81
# 200
# 91 overlaps fixed. Making another pass...
# 82
# 200
# 129 overlaps fixed. Making another pass...
# 83
# 200
# 137 overlaps fixed. Making another pass...
# 84
# 200
# 123 overlaps fixed. Making another pass...
# 85
# 200
# 92 overlaps fixed. Making another pass...
# 86
# 200
# 100 overlaps fixed. Making another pass...
# 87
# 200
# 109 overlaps fixed. Making another pass...
# 88
# 200
# 84 overlaps fixed. Making another pass...
# 89
# 200
# 124 overlaps fixed. Making another pass...
# 90
# 200
# 109 overlaps fixed. Making another pass...
# 91
# 200
# 121 overlaps fixed. Making another pass...
# 92
# 200
# 105 overlaps fixed. Making another pass...
# 93
# 200
# 104 overlaps fixed. Making another pass...
# 94
# 200
# 120 overlaps fixed. Making another pass...
# 95
# 200
# 105 overlaps fixed. Making another pass...
# 96
# 200
# 111 overlaps fixed. Making another pass...
# 97
# 200
# 110 overlaps fixed. Making another pass...
# 98
# 200
# 129 overlaps fixed. Making another pass...
# 99
# 200
# 109 overlaps fixed. Making another pass...
# 100
# 200
# 153 overlaps fixed. Making another pass...
# 101
# 200
# 108 overlaps fixed. Making another pass...
# 102
# 200
# 130 overlaps fixed. Making another pass...
# 103
# 200
# 135 overlaps fixed. Making another pass...
# 104
# 200
# 132 overlaps fixed. Making another pass...
# 105
# 200
# 149 overlaps fixed. Making another pass...
# 106
# 200
# 126 overlaps fixed. Making another pass...
# 107
# 200
# 127 overlaps fixed. Making another pass...
# 108
# 200
# 98 overlaps fixed. Making another pass...
# 109
# 200
# 98 overlaps fixed. Making another pass...
# 110
# 200
# 118 overlaps fixed. Making another pass...
# 111
# 200
# 115 overlaps fixed. Making another pass...
# 112
# 200
# 110 overlaps fixed. Making another pass...
# 113
# 200
# 99 overlaps fixed. Making another pass...
# 114
# 200
# 134 overlaps fixed. Making another pass...
# 115
# 200
# 87 overlaps fixed. Making another pass...
# 116
# 200
# 104 overlaps fixed. Making another pass...
# 117
# 200
# 119 overlaps fixed. Making another pass...
# 118
# 200
# 122 overlaps fixed. Making another pass...
# 119
# 200
# 130 overlaps fixed. Making another pass...
# 120
# 200
# 129 overlaps fixed. Making another pass...
# 121
# 200
# 113 overlaps fixed. Making another pass...
# 122
# 200
# 137 overlaps fixed. Making another pass...
# 123
# 200
# 134 overlaps fixed. Making another pass...
# 124
# 200
# 118 overlaps fixed. Making another pass...
# 125
# 200
# 132 overlaps fixed. Making another pass...
# 126
# 200
# 99 overlaps fixed. Making another pass...
# 127
# 200
# 126 overlaps fixed. Making another pass...
# 128
# 200
# 88 overlaps fixed. Making another pass...
# 129
# 200
# 78 overlaps fixed. Making another pass...
# 130
# 200
# 71 overlaps fixed. Making another pass...
# 131
# 200
# 96 overlaps fixed. Making another pass...
# 132
# 200
# 92 overlaps fixed. Making another pass...
# 133
# 200
# 107 overlaps fixed. Making another pass...
# 134
# 200
# 95 overlaps fixed. Making another pass...
# 135
# 200
# 92 overlaps fixed. Making another pass...
# 136
# 200
# 129 overlaps fixed. Making another pass...
# 137
# 200
# 125 overlaps fixed. Making another pass...
# 138
# 200
# 84 overlaps fixed. Making another pass...
# 139
# 200
# 79 overlaps fixed. Making another pass...
# 140
# 200
# 79 overlaps fixed. Making another pass...
# 141
# 200
# 91 overlaps fixed. Making another pass...
# 142
# 200
# 105 overlaps fixed. Making another pass...
# 143
# 200
# 78 overlaps fixed. Making another pass...
# 144
# 200
# 57 overlaps fixed. Making another pass...
# 145
# 200
# 77 overlaps fixed. Making another pass...
# 146
# 200
# 72 overlaps fixed. Making another pass...
# 147
# 200
# 98 overlaps fixed. Making another pass...
# 148
# 200
# 90 overlaps fixed. Making another pass...
# 149
# 200
# 119 overlaps fixed. Making another pass...
# 150
# 200
# 95 overlaps fixed. Making another pass...
# 151
# 200
# 90 overlaps fixed. Making another pass...
# 152
# 200
# 107 overlaps fixed. Making another pass...
# 153
# 200
# 96 overlaps fixed. Making another pass...
# 154
# 200
# 96 overlaps fixed. Making another pass...
# 155
# 200
# 114 overlaps fixed. Making another pass...
# 156
# 200
# 94 overlaps fixed. Making another pass...
# 157
# 200
# 87 overlaps fixed. Making another pass...
# 158
# 200
# 91 overlaps fixed. Making another pass...
# 159
# 200
# 118 overlaps fixed. Making another pass...
# 160
# 200
# 149 overlaps fixed. Making another pass...
# 161
# 200
# 106 overlaps fixed. Making another pass...
# 162
# 200
# 125 overlaps fixed. Making another pass...
# 163
# 200
# 95 overlaps fixed. Making another pass...
# 164
# 200
# 97 overlaps fixed. Making another pass...
# 165
# 200
# 94 overlaps fixed. Making another pass...
# 166
# 200
# 127 overlaps fixed. Making another pass...
# 167
# 200
# 114 overlaps fixed. Making another pass...
# 168
# 200
# 110 overlaps fixed. Making another pass...
# 169
# 200
# 110 overlaps fixed. Making another pass...
# 170
# 200
# 112 overlaps fixed. Making another pass...
# 171
# 200
# 73 overlaps fixed. Making another pass...
# 172
# 200
# 91 overlaps fixed. Making another pass...
# 173
# 200
# 111 overlaps fixed. Making another pass...
# 174
# 200
# 106 overlaps fixed. Making another pass...
# 175
# 200
# 124 overlaps fixed. Making another pass...
# 176
# 200
# 126 overlaps fixed. Making another pass...
# 177
# 200
# 124 overlaps fixed. Making another pass...
# 178
# 200
# 97 overlaps fixed. Making another pass...
# 179
# 200
# 100 overlaps fixed. Making another pass...
# 180
# 200
# 72 overlaps fixed. Making another pass...
# 181
# 200
# 70 overlaps fixed. Making another pass...
# 182
# 200
# 99 overlaps fixed. Making another pass...
# 183
# 200
# 81 overlaps fixed. Making another pass...
# 184
# 200
# 67 overlaps fixed. Making another pass...
# 185
# 200
# 79 overlaps fixed. Making another pass...
# 186
# 200
# 113 overlaps fixed. Making another pass...
# 187
# 200
# 90 overlaps fixed. Making another pass...
# 188
# 200
# 76 overlaps fixed. Making another pass...
# 189
# 200
# 98 overlaps fixed. Making another pass...
# 190
# 200
# 104 overlaps fixed. Making another pass...
# 191
# 200
# 83 overlaps fixed. Making another pass...
# 192
# 200
# 127 overlaps fixed. Making another pass...
# 193
# 200
# 121 overlaps fixed. Making another pass...
# 194
# 200
# 164 overlaps fixed. Making another pass...
# 195
# 200
# 137 overlaps fixed. Making another pass...
# 196
# 200
# 138 overlaps fixed. Making another pass...
# 197
# 200
# 109 overlaps fixed. Making another pass...
# 198
# 200
# 108 overlaps fixed. Making another pass...
# 199
# 200
# 115 overlaps fixed. Making another pass...
# 200
# 200
# 100 overlaps fixed. Making another pass...
# 201
# 200
# 258 overlaps fixed. Making another pass...
# 1
# 200
# 198 overlaps fixed. Making another pass...
# 2
# 200
# 156 overlaps fixed. Making another pass...
# 3
# 200
# 111 overlaps fixed. Making another pass...
# 4
# 200
# 109 overlaps fixed. Making another pass...
# 5
# 200
# 106 overlaps fixed. Making another pass...
# 6
# 200
# 111 overlaps fixed. Making another pass...
# 7
# 200
# 119 overlaps fixed. Making another pass...
# 8
# 200
# 119 overlaps fixed. Making another pass...
# 9
# 200
# 93 overlaps fixed. Making another pass...
# 10
# 200
# 111 overlaps fixed. Making another pass...
# 11
# 200
# 128 overlaps fixed. Making another pass...
# 12
# 200
# 112 overlaps fixed. Making another pass...
# 13
# 200
# 109 overlaps fixed. Making another pass...
# 14
# 200
# 84 overlaps fixed. Making another pass...
# 15
# 200
# 86 overlaps fixed. Making another pass...
# 16
# 200
# 79 overlaps fixed. Making another pass...
# 17
# 200
# 82 overlaps fixed. Making another pass...
# 18
# 200
# 112 overlaps fixed. Making another pass...
# 19
# 200
# 120 overlaps fixed. Making another pass...
# 20
# 200
# 85 overlaps fixed. Making another pass...
# 21
# 200
# 85 overlaps fixed. Making another pass...
# 22
# 200
# 106 overlaps fixed. Making another pass...
# 23
# 200
# 103 overlaps fixed. Making another pass...
# 24
# 200
# 118 overlaps fixed. Making another pass...
# 25
# 200
# 110 overlaps fixed. Making another pass...
# 26
# 200
# 119 overlaps fixed. Making another pass...
# 27
# 200
# 138 overlaps fixed. Making another pass...
# 28
# 200
# 133 overlaps fixed. Making another pass...
# 29
# 200
# 104 overlaps fixed. Making another pass...
# 30
# 200
# 126 overlaps fixed. Making another pass...
# 31
# 200
# 109 overlaps fixed. Making another pass...
# 32
# 200
# 146 overlaps fixed. Making another pass...
# 33
# 200
# 119 overlaps fixed. Making another pass...
# 34
# 200
# 116 overlaps fixed. Making another pass...
# 35
# 200
# 148 overlaps fixed. Making another pass...
# 36
# 200
# 123 overlaps fixed. Making another pass...
# 37
# 200
# 100 overlaps fixed. Making another pass...
# 38
# 200
# 105 overlaps fixed. Making another pass...
# 39
# 200
# 114 overlaps fixed. Making another pass...
# 40
# 200
# 118 overlaps fixed. Making another pass...
# 41
# 200
# 114 overlaps fixed. Making another pass...
# 42
# 200
# 113 overlaps fixed. Making another pass...
# 43
# 200
# 101 overlaps fixed. Making another pass...
# 44
# 200
# 93 overlaps fixed. Making another pass...
# 45
# 200
# 95 overlaps fixed. Making another pass...
# 46
# 200
# 98 overlaps fixed. Making another pass...
# 47
# 200
# 92 overlaps fixed. Making another pass...
# 48
# 200
# 105 overlaps fixed. Making another pass...
# 49
# 200
# 98 overlaps fixed. Making another pass...
# 50
# 200
# 87 overlaps fixed. Making another pass...
# 51
# 200
# 74 overlaps fixed. Making another pass...
# 52
# 200
# 96 overlaps fixed. Making another pass...
# 53
# 200
# 82 overlaps fixed. Making another pass...
# 54
# 200
# 125 overlaps fixed. Making another pass...
# 55
# 200
# 87 overlaps fixed. Making another pass...
# 56
# 200
# 119 overlaps fixed. Making another pass...
# 57
# 200
# 125 overlaps fixed. Making another pass...
# 58
# 200
# 108 overlaps fixed. Making another pass...
# 59
# 200
# 108 overlaps fixed. Making another pass...
# 60
# 200
# 115 overlaps fixed. Making another pass...
# 61
# 200
# 122 overlaps fixed. Making another pass...
# 62
# 200
# 118 overlaps fixed. Making another pass...
# 63
# 200
# 114 overlaps fixed. Making another pass...
# 64
# 200
# 114 overlaps fixed. Making another pass...
# 65
# 200
# 102 overlaps fixed. Making another pass...
# 66
# 200
# 110 overlaps fixed. Making another pass...
# 67
# 200
# 90 overlaps fixed. Making another pass...
# 68
# 200
# 95 overlaps fixed. Making another pass...
# 69
# 200
# 112 overlaps fixed. Making another pass...
# 70
# 200
# 123 overlaps fixed. Making another pass...
# 71
# 200
# 108 overlaps fixed. Making another pass...
# 72
# 200
# 122 overlaps fixed. Making another pass...
# 73
# 200
# 132 overlaps fixed. Making another pass...
# 74
# 200
# 119 overlaps fixed. Making another pass...
# 75
# 200
# 108 overlaps fixed. Making another pass...
# 76
# 200
# 93 overlaps fixed. Making another pass...
# 77
# 200
# 102 overlaps fixed. Making another pass...
# 78
# 200
# 110 overlaps fixed. Making another pass...
# 79
# 200
# 121 overlaps fixed. Making another pass...
# 80
# 200
# 107 overlaps fixed. Making another pass...
# 81
# 200
# 93 overlaps fixed. Making another pass...
# 82
# 200
# 96 overlaps fixed. Making another pass...
# 83
# 200
# 102 overlaps fixed. Making another pass...
# 84
# 200
# 122 overlaps fixed. Making another pass...
# 85
# 200
# 120 overlaps fixed. Making another pass...
# 86
# 200
# 108 overlaps fixed. Making another pass...
# 87
# 200
# 112 overlaps fixed. Making another pass...
# 88
# 200
# 149 overlaps fixed. Making another pass...
# 89
# 200
# 144 overlaps fixed. Making another pass...
# 90
# 200
# 121 overlaps fixed. Making another pass...
# 91
# 200
# 103 overlaps fixed. Making another pass...
# 92
# 200
# 91 overlaps fixed. Making another pass...
# 93
# 200
# 125 overlaps fixed. Making another pass...
# 94
# 200
# 112 overlaps fixed. Making another pass...
# 95
# 200
# 85 overlaps fixed. Making another pass...
# 96
# 200
# 100 overlaps fixed. Making another pass...
# 97
# 200
# 87 overlaps fixed. Making another pass...
# 98
# 200
# 91 overlaps fixed. Making another pass...
# 99
# 200
# 92 overlaps fixed. Making another pass...
# 100
# 200
# 98 overlaps fixed. Making another pass...
# 101
# 200
# 115 overlaps fixed. Making another pass...
# 102
# 200
# 108 overlaps fixed. Making another pass...
# 103
# 200
# 118 overlaps fixed. Making another pass...
# 104
# 200
# 126 overlaps fixed. Making another pass...
# 105
# 200
# 110 overlaps fixed. Making another pass...
# 106
# 200
# 106 overlaps fixed. Making another pass...
# 107
# 200
# 112 overlaps fixed. Making another pass...
# 108
# 200
# 96 overlaps fixed. Making another pass...
# 109
# 200
# 119 overlaps fixed. Making another pass...
# 110
# 200
# 97 overlaps fixed. Making another pass...
# 111
# 200
# 92 overlaps fixed. Making another pass...
# 112
# 200
# 105 overlaps fixed. Making another pass...
# 113
# 200
# 132 overlaps fixed. Making another pass...
# 114
# 200
# 128 overlaps fixed. Making another pass...
# 115
# 200
# 103 overlaps fixed. Making another pass...
# 116
# 200
# 114 overlaps fixed. Making another pass...
# 117
# 200
# 113 overlaps fixed. Making another pass...
# 118
# 200
# 108 overlaps fixed. Making another pass...
# 119
# 200
# 109 overlaps fixed. Making another pass...
# 120
# 200
# 109 overlaps fixed. Making another pass...
# 121
# 200
# 108 overlaps fixed. Making another pass...
# 122
# 200
# 120 overlaps fixed. Making another pass...
# 123
# 200
# 95 overlaps fixed. Making another pass...
# 124
# 200
# 93 overlaps fixed. Making another pass...
# 125
# 200
# 103 overlaps fixed. Making another pass...
# 126
# 200
# 116 overlaps fixed. Making another pass...
# 127
# 200
# 108 overlaps fixed. Making another pass...
# 128
# 200
# 120 overlaps fixed. Making another pass...
# 129
# 200
# 117 overlaps fixed. Making another pass...
# 130
# 200
# 173 overlaps fixed. Making another pass...
# 131
# 200
# 129 overlaps fixed. Making another pass...
# 132
# 200
# 104 overlaps fixed. Making another pass...
# 133
# 200
# 116 overlaps fixed. Making another pass...
# 134
# 200
# 120 overlaps fixed. Making another pass...
# 135
# 200
# 117 overlaps fixed. Making another pass...
# 136
# 200
# 103 overlaps fixed. Making another pass...
# 137
# 200
# 113 overlaps fixed. Making another pass...
# 138
# 200
# 122 overlaps fixed. Making another pass...
# 139
# 200
# 112 overlaps fixed. Making another pass...
# 140
# 200
# 96 overlaps fixed. Making another pass...
# 141
# 200
# 114 overlaps fixed. Making another pass...
# 142
# 200
# 97 overlaps fixed. Making another pass...
# 143
# 200
# 122 overlaps fixed. Making another pass...
# 144
# 200
# 118 overlaps fixed. Making another pass...
# 145
# 200
# 128 overlaps fixed. Making another pass...
# 146
# 200
# 183 overlaps fixed. Making another pass...
# 147
# 200
# 109 overlaps fixed. Making another pass...
# 148
# 200
# 111 overlaps fixed. Making another pass...
# 149
# 200
# 79 overlaps fixed. Making another pass...
# 150
# 200
# 108 overlaps fixed. Making another pass...
# 151
# 200
# 93 overlaps fixed. Making another pass...
# 152
# 200
# 87 overlaps fixed. Making another pass...
# 153
# 200
# 111 overlaps fixed. Making another pass...
# 154
# 200
# 82 overlaps fixed. Making another pass...
# 155
# 200
# 124 overlaps fixed. Making another pass...
# 156
# 200
# 118 overlaps fixed. Making another pass...
# 157
# 200
# 118 overlaps fixed. Making another pass...
# 158
# 200
# 102 overlaps fixed. Making another pass...
# 159
# 200
# 121 overlaps fixed. Making another pass...
# 160
# 200
# 113 overlaps fixed. Making another pass...
# 161
# 200
# 107 overlaps fixed. Making another pass...
# 162
# 200
# 120 overlaps fixed. Making another pass...
# 163
# 200
# 109 overlaps fixed. Making another pass...
# 164
# 200
# 130 overlaps fixed. Making another pass...
# 165
# 200
# 93 overlaps fixed. Making another pass...
# 166
# 200
# 107 overlaps fixed. Making another pass...
# 167
# 200
# 113 overlaps fixed. Making another pass...
# 168
# 200
# 123 overlaps fixed. Making another pass...
# 169
# 200
# 91 overlaps fixed. Making another pass...
# 170
# 200
# 118 overlaps fixed. Making another pass...
# 171
# 200
# 106 overlaps fixed. Making another pass...
# 172
# 200
# 108 overlaps fixed. Making another pass...
# 173
# 200
# 108 overlaps fixed. Making another pass...
# 174
# 200
# 109 overlaps fixed. Making another pass...
# 175
# 200
# 124 overlaps fixed. Making another pass...
# 176
# 200
# 85 overlaps fixed. Making another pass...
# 177
# 200
# 115 overlaps fixed. Making another pass...
# 178
# 200
# 120 overlaps fixed. Making another pass...
# 179
# 200
# 94 overlaps fixed. Making another pass...
# 180
# 200
# 110 overlaps fixed. Making another pass...
# 181
# 200
# 82 overlaps fixed. Making another pass...
# 182
# 200
# 90 overlaps fixed. Making another pass...
# 183
# 200
# 99 overlaps fixed. Making another pass...
# 184
# 200
# 113 overlaps fixed. Making another pass...
# 185
# 200
# 103 overlaps fixed. Making another pass...
# 186
# 200
# 108 overlaps fixed. Making another pass...
# 187
# 200
# 78 overlaps fixed. Making another pass...
# 188
# 200
# 87 overlaps fixed. Making another pass...
# 189
# 200
# 99 overlaps fixed. Making another pass...
# 190
# 200
# 122 overlaps fixed. Making another pass...
# 191
# 200
# 90 overlaps fixed. Making another pass...
# 192
# 200
# 89 overlaps fixed. Making another pass...
# 193
# 200
# 141 overlaps fixed. Making another pass...
# 194
# 200
# 111 overlaps fixed. Making another pass...
# 195
# 200
# 131 overlaps fixed. Making another pass...
# 196
# 200
# 129 overlaps fixed. Making another pass...
# 197
# 200
# 91 overlaps fixed. Making another pass...
# 198
# 200
# 121 overlaps fixed. Making another pass...
# 199
# 200
# 94 overlaps fixed. Making another pass...
# 200
# 200
# 106 overlaps fixed. Making another pass...
# 201
# 200
# 307 overlaps fixed. Making another pass...
# 1
# 200
# 179 overlaps fixed. Making another pass...
# 2
# 200
# 159 overlaps fixed. Making another pass...
# 3
# 200
# 109 overlaps fixed. Making another pass...
# 4
# 200
# 107 overlaps fixed. Making another pass...
# 5
# 200
# 95 overlaps fixed. Making another pass...
# 6
# 200
# 124 overlaps fixed. Making another pass...
# 7
# 200
# 99 overlaps fixed. Making another pass...
# 8
# 200
# 74 overlaps fixed. Making another pass...
# 9
# 200
# 99 overlaps fixed. Making another pass...
# 10
# 200
# 131 overlaps fixed. Making another pass...
# 11
# 200
# 118 overlaps fixed. Making another pass...
# 12
# 200
# 115 overlaps fixed. Making another pass...
# 13
# 200
# 140 overlaps fixed. Making another pass...
# 14
# 200
# 137 overlaps fixed. Making another pass...
# 15
# 200
# 121 overlaps fixed. Making another pass...
# 16
# 200
# 112 overlaps fixed. Making another pass...
# 17
# 200
# 137 overlaps fixed. Making another pass...
# 18
# 200
# 113 overlaps fixed. Making another pass...
# 19
# 200
# 131 overlaps fixed. Making another pass...
# 20
# 200
# 121 overlaps fixed. Making another pass...
# 21
# 200
# 111 overlaps fixed. Making another pass...
# 22
# 200
# 118 overlaps fixed. Making another pass...
# 23
# 200
# 157 overlaps fixed. Making another pass...
# 24
# 200
# 161 overlaps fixed. Making another pass...
# 25
# 200
# 158 overlaps fixed. Making another pass...
# 26
# 200
# 106 overlaps fixed. Making another pass...
# 27
# 200
# 124 overlaps fixed. Making another pass...
# 28
# 200
# 146 overlaps fixed. Making another pass...
# 29
# 200
# 142 overlaps fixed. Making another pass...
# 30
# 200
# 106 overlaps fixed. Making another pass...
# 31
# 200
# 98 overlaps fixed. Making another pass...
# 32
# 200
# 116 overlaps fixed. Making another pass...
# 33
# 200
# 103 overlaps fixed. Making another pass...
# 34
# 200
# 103 overlaps fixed. Making another pass...
# 35
# 200
# 116 overlaps fixed. Making another pass...
# 36
# 200
# 112 overlaps fixed. Making another pass...
# 37
# 200
# 99 overlaps fixed. Making another pass...
# 38
# 200
# 101 overlaps fixed. Making another pass...
# 39
# 200
# 83 overlaps fixed. Making another pass...
# 40
# 200
# 125 overlaps fixed. Making another pass...
# 41
# 200
# 118 overlaps fixed. Making another pass...
# 42
# 200
# 119 overlaps fixed. Making another pass...
# 43
# 200
# 93 overlaps fixed. Making another pass...
# 44
# 200
# 121 overlaps fixed. Making another pass...
# 45
# 200
# 110 overlaps fixed. Making another pass...
# 46
# 200
# 101 overlaps fixed. Making another pass...
# 47
# 200
# 115 overlaps fixed. Making another pass...
# 48
# 200
# 109 overlaps fixed. Making another pass...
# 49
# 200
# 128 overlaps fixed. Making another pass...
# 50
# 200
# 135 overlaps fixed. Making another pass...
# 51
# 200
# 120 overlaps fixed. Making another pass...
# 52
# 200
# 121 overlaps fixed. Making another pass...
# 53
# 200
# 154 overlaps fixed. Making another pass...
# 54
# 200
# 111 overlaps fixed. Making another pass...
# 55
# 200
# 115 overlaps fixed. Making another pass...
# 56
# 200
# 114 overlaps fixed. Making another pass...
# 57
# 200
# 99 overlaps fixed. Making another pass...
# 58
# 200
# 116 overlaps fixed. Making another pass...
# 59
# 200
# 125 overlaps fixed. Making another pass...
# 60
# 200
# 132 overlaps fixed. Making another pass...
# 61
# 200
# 123 overlaps fixed. Making another pass...
# 62
# 200
# 165 overlaps fixed. Making another pass...
# 63
# 200
# 91 overlaps fixed. Making another pass...
# 64
# 200
# 96 overlaps fixed. Making another pass...
# 65
# 200
# 94 overlaps fixed. Making another pass...
# 66
# 200
# 119 overlaps fixed. Making another pass...
# 67
# 200
# 130 overlaps fixed. Making another pass...
# 68
# 200
# 101 overlaps fixed. Making another pass...
# 69
# 200
# 144 overlaps fixed. Making another pass...
# 70
# 200
# 128 overlaps fixed. Making another pass...
# 71
# 200
# 135 overlaps fixed. Making another pass...
# 72
# 200
# 91 overlaps fixed. Making another pass...
# 73
# 200
# 110 overlaps fixed. Making another pass...
# 74
# 200
# 88 overlaps fixed. Making another pass...
# 75
# 200
# 85 overlaps fixed. Making another pass...
# 76
# 200
# 80 overlaps fixed. Making another pass...
# 77
# 200
# 100 overlaps fixed. Making another pass...
# 78
# 200
# 106 overlaps fixed. Making another pass...
# 79
# 200
# 97 overlaps fixed. Making another pass...
# 80
# 200
# 98 overlaps fixed. Making another pass...
# 81
# 200
# 114 overlaps fixed. Making another pass...
# 82
# 200
# 96 overlaps fixed. Making another pass...
# 83
# 200
# 112 overlaps fixed. Making another pass...
# 84
# 200
# 116 overlaps fixed. Making another pass...
# 85
# 200
# 106 overlaps fixed. Making another pass...
# 86
# 200
# 114 overlaps fixed. Making another pass...
# 87
# 200
# 116 overlaps fixed. Making another pass...
# 88
# 200
# 127 overlaps fixed. Making another pass...
# 89
# 200
# 114 overlaps fixed. Making another pass...
# 90
# 200
# 113 overlaps fixed. Making another pass...
# 91
# 200
# 122 overlaps fixed. Making another pass...
# 92
# 200
# 86 overlaps fixed. Making another pass...
# 93
# 200
# 102 overlaps fixed. Making another pass...
# 94
# 200
# 131 overlaps fixed. Making another pass...
# 95
# 200
# 92 overlaps fixed. Making another pass...
# 96
# 200
# 101 overlaps fixed. Making another pass...
# 97
# 200
# 119 overlaps fixed. Making another pass...
# 98
# 200
# 97 overlaps fixed. Making another pass...
# 99
# 200
# 99 overlaps fixed. Making another pass...
# 100
# 200
# 97 overlaps fixed. Making another pass...
# 101
# 200
# 107 overlaps fixed. Making another pass...
# 102
# 200
# 98 overlaps fixed. Making another pass...
# 103
# 200
# 123 overlaps fixed. Making another pass...
# 104
# 200
# 100 overlaps fixed. Making another pass...
# 105
# 200
# 121 overlaps fixed. Making another pass...
# 106
# 200
# 90 overlaps fixed. Making another pass...
# 107
# 200
# 111 overlaps fixed. Making another pass...
# 108
# 200
# 95 overlaps fixed. Making another pass...
# 109
# 200
# 104 overlaps fixed. Making another pass...
# 110
# 200
# 124 overlaps fixed. Making another pass...
# 111
# 200
# 98 overlaps fixed. Making another pass...
# 112
# 200
# 93 overlaps fixed. Making another pass...
# 113
# 200
# 104 overlaps fixed. Making another pass...
# 114
# 200
# 115 overlaps fixed. Making another pass...
# 115
# 200
# 121 overlaps fixed. Making another pass...
# 116
# 200
# 104 overlaps fixed. Making another pass...
# 117
# 200
# 142 overlaps fixed. Making another pass...
# 118
# 200
# 120 overlaps fixed. Making another pass...
# 119
# 200
# 139 overlaps fixed. Making another pass...
# 120
# 200
# 124 overlaps fixed. Making another pass...
# 121
# 200
# 102 overlaps fixed. Making another pass...
# 122
# 200
# 82 overlaps fixed. Making another pass...
# 123
# 200
# 75 overlaps fixed. Making another pass...
# 124
# 200
# 66 overlaps fixed. Making another pass...
# 125
# 200
# 74 overlaps fixed. Making another pass...
# 126
# 200
# 76 overlaps fixed. Making another pass...
# 127
# 200
# 73 overlaps fixed. Making another pass...
# 128
# 200
# 87 overlaps fixed. Making another pass...
# 129
# 200
# 90 overlaps fixed. Making another pass...
# 130
# 200
# 96 overlaps fixed. Making another pass...
# 131
# 200
# 88 overlaps fixed. Making another pass...
# 132
# 200
# 90 overlaps fixed. Making another pass...
# 133
# 200
# 105 overlaps fixed. Making another pass...
# 134
# 200
# 98 overlaps fixed. Making another pass...
# 135
# 200
# 141 overlaps fixed. Making another pass...
# 136
# 200
# 127 overlaps fixed. Making another pass...
# 137
# 200
# 126 overlaps fixed. Making another pass...
# 138
# 200
# 99 overlaps fixed. Making another pass...
# 139
# 200
# 144 overlaps fixed. Making another pass...
# 140
# 200
# 120 overlaps fixed. Making another pass...
# 141
# 200
# 103 overlaps fixed. Making another pass...
# 142
# 200
# 100 overlaps fixed. Making another pass...
# 143
# 200
# 84 overlaps fixed. Making another pass...
# 144
# 200
# 102 overlaps fixed. Making another pass...
# 145
# 200
# 129 overlaps fixed. Making another pass...
# 146
# 200
# 113 overlaps fixed. Making another pass...
# 147
# 200
# 98 overlaps fixed. Making another pass...
# 148
# 200
# 107 overlaps fixed. Making another pass...
# 149
# 200
# 106 overlaps fixed. Making another pass...
# 150
# 200
# 98 overlaps fixed. Making another pass...
# 151
# 200
# 91 overlaps fixed. Making another pass...
# 152
# 200
# ...
# 89
# 200
# 56 overlaps fixed. Making another pass...
# 90
# 200
# 65 overlaps fixed. Making another pass...
# 91
# 200
# 78 overlaps fixed. Making another pass...
# 92
# 200
# 88 overlaps fixed. Making another pass...
# 93
# 200
# 109 overlaps fixed. Making another pass...
# 94
# 200
# 74 overlaps fixed. Making another pass...
# 95
# 200
# 131 overlaps fixed. Making another pass...
# 96
# 200
# 116 overlaps fixed. Making another pass...
# 97
# 200
# 102 overlaps fixed. Making another pass...
# 98
# 200
# 93 overlaps fixed. Making another pass...
# 99
# 200
# 124 overlaps fixed. Making another pass...
# 100
# 200
# 116 overlaps fixed. Making another pass...
# 101
# 200
# 113 overlaps fixed. Making another pass...
# 102
# 200
# 100 overlaps fixed. Making another pass...
# 103
# 200
# 104 overlaps fixed. Making another pass...
# 104
# 200
# 99 overlaps fixed. Making another pass...
# 105
# 200
# 116 overlaps fixed. Making another pass...
# 106
# 200
# 101 overlaps fixed. Making another pass...
# 107
# 200
# 95 overlaps fixed. Making another pass...
# 108
# 200
# 129 overlaps fixed. Making another pass...
# 109
# 200
# 127 overlaps fixed. Making another pass...
# 110
# 200
# 148 overlaps fixed. Making another pass...
# 111
# 200
# 117 overlaps fixed. Making another pass...
# 112
# 200
# 117 overlaps fixed. Making another pass...
# 113
# 200
# 139 overlaps fixed. Making another pass...
# 114
# 200
# 143 overlaps fixed. Making another pass...
# 115
# 200
# 130 overlaps fixed. Making another pass...
# 116
# 200
# 104 overlaps fixed. Making another pass...
# 117
# 200
# 112 overlaps fixed. Making another pass...
# 118
# 200
# 131 overlaps fixed. Making another pass...
# 119
# 200
# 103 overlaps fixed. Making another pass...
# 120
# 200
# 97 overlaps fixed. Making another pass...
# 121
# 200
# 90 overlaps fixed. Making another pass...
# 122
# 200
# 86 overlaps fixed. Making another pass...
# 123
# 200
# 106 overlaps fixed. Making another pass...
# 124
# 200
# 98 overlaps fixed. Making another pass...
# 125
# 200
# 120 overlaps fixed. Making another pass...
# 126
# 200
# 102 overlaps fixed. Making another pass...
# 127
# 200
# 100 overlaps fixed. Making another pass...
# 128
# 200
# 106 overlaps fixed. Making another pass...
# 129
# 200
# 118 overlaps fixed. Making another pass...
# 130
# 200
# 130 overlaps fixed. Making another pass...
# 131
# 200
# 90 overlaps fixed. Making another pass...
# 132
# 200
# 93 overlaps fixed. Making another pass...
# 133
# 200
# 92 overlaps fixed. Making another pass...
# 134
# 200
# 95 overlaps fixed. Making another pass...
# 135
# 200
# 122 overlaps fixed. Making another pass...
# 136
# 200
# 110 overlaps fixed. Making another pass...
# 137
# 200
# 130 overlaps fixed. Making another pass...
# 138
# 200
# 99 overlaps fixed. Making another pass...
# 139
# 200
# 128 overlaps fixed. Making another pass...
# 140
# 200
# 113 overlaps fixed. Making another pass...
# 141
# 200
# 105 overlaps fixed. Making another pass...
# 142
# 200
# 111 overlaps fixed. Making another pass...
# 143
# 200
# 107 overlaps fixed. Making another pass...
# 144
# 200
# 103 overlaps fixed. Making another pass...
# 145
# 200
# 88 overlaps fixed. Making another pass...
# 146
# 200
# 134 overlaps fixed. Making another pass...
# 147
# 200
# 129 overlaps fixed. Making another pass...
# 148
# 200
# 106 overlaps fixed. Making another pass...
# 149
# 200
# 107 overlaps fixed. Making another pass...
# 150
# 200
# 118 overlaps fixed. Making another pass...
# 151
# 200
# 98 overlaps fixed. Making another pass...
# 152
# 200
# 98 overlaps fixed. Making another pass...
# 153
# 200
# 87 overlaps fixed. Making another pass...
# 154
# 200
# 109 overlaps fixed. Making another pass...
# 155
# 200
# 113 overlaps fixed. Making another pass...
# 156
# 200
# 102 overlaps fixed. Making another pass...
# 157
# 200
# 100 overlaps fixed. Making another pass...
# 158
# 200
# 96 overlaps fixed. Making another pass...
# 159
# 200
# 107 overlaps fixed. Making another pass...
# 160
# 200
# 106 overlaps fixed. Making another pass...
# 161
# 200
# 128 overlaps fixed. Making another pass...
# 162
# 200
# 100 overlaps fixed. Making another pass...
# 163
# 200
# 80 overlaps fixed. Making another pass...
# 164
# 200
# 90 overlaps fixed. Making another pass...
# 165
# 200
# 126 overlaps fixed. Making another pass...
# 166
# 200
# 102 overlaps fixed. Making another pass...
# 167
# 200
# 115 overlaps fixed. Making another pass...
# 168
# 200
# 123 overlaps fixed. Making another pass...
# 169
# 200
# 116 overlaps fixed. Making another pass...
# 170
# 200
# 101 overlaps fixed. Making another pass...
# 171
# 200
# 82 overlaps fixed. Making another pass...
# 172
# 200
# 85 overlaps fixed. Making another pass...
# 173
# 200
# 81 overlaps fixed. Making another pass...
# 174
# 200
# 105 overlaps fixed. Making another pass...
# 175
# 200
# 93 overlaps fixed. Making another pass...
# 176
# 200
# 88 overlaps fixed. Making another pass...
# 177
# 200
# 80 overlaps fixed. Making another pass...
# 178
# 200
# 81 overlaps fixed. Making another pass...
# 179
# 200
# 70 overlaps fixed. Making another pass...
# 180
# 200
# 86 overlaps fixed. Making another pass...
# 181
# 200
# 88 overlaps fixed. Making another pass...
# 182
# 200
# 97 overlaps fixed. Making another pass...
# 183
# 200
# 84 overlaps fixed. Making another pass...
# 184
# 200
# 101 overlaps fixed. Making another pass...
# 185
# 200
# 89 overlaps fixed. Making another pass...
# 186
# 200
# 84 overlaps fixed. Making another pass...
# 187
# 200
# 94 overlaps fixed. Making another pass...
# 188
# 200
# 97 overlaps fixed. Making another pass...
# 189
# 200
# 106 overlaps fixed. Making another pass...
# 190
# 200
# 104 overlaps fixed. Making another pass...
# 191
# 200
# 96 overlaps fixed. Making another pass...
# 192
# 200
# 128 overlaps fixed. Making another pass...
# 193
# 200
# 99 overlaps fixed. Making another pass...
# 194
# 200
# 114 overlaps fixed. Making another pass...
# 195
# 200
# 101 overlaps fixed. Making another pass...
# 196
# 200
# 97 overlaps fixed. Making another pass...
# 197
# 200
# 83 overlaps fixed. Making another pass...
# 198
# 200
# 84 overlaps fixed. Making another pass...
# 199
# 200
# 97 overlaps fixed. Making another pass...
# 200
# 200
# 101 overlaps fixed. Making another pass...
# 201
# 200
# 327 overlaps fixed. Making another pass...
# 1
# 200
# 175 overlaps fixed. Making another pass...
# 2
# 200
# 151 overlaps fixed. Making another pass...
# 3
# 200
# 161 overlaps fixed. Making another pass...
# 4
# 200
# 114 overlaps fixed. Making another pass...
# 5
# 200
# 147 overlaps fixed. Making another pass...
# 6
# 200
# 99 overlaps fixed. Making another pass...
# 7
# 200
# 116 overlaps fixed. Making another pass...
# 8
# 200
# 120 overlaps fixed. Making another pass...
# 9
# 200
# 124 overlaps fixed. Making another pass...
# 10
# 200
# 122 overlaps fixed. Making another pass...
# 11
# 200
# 103 overlaps fixed. Making another pass...
# 12
# 200
# 111 overlaps fixed. Making another pass...
# 13
# 200
# 138 overlaps fixed. Making another pass...
# 14
# 200
# 90 overlaps fixed. Making another pass...
# 15
# 200
# 83 overlaps fixed. Making another pass...
# 16
# 200
# 110 overlaps fixed. Making another pass...
# 17
# 200
# 132 overlaps fixed. Making another pass...
# 18
# 200
# 141 overlaps fixed. Making another pass...
# 19
# 200
# 114 overlaps fixed. Making another pass...
# 20
# 200
# 102 overlaps fixed. Making another pass...
# 21
# 200
# 105 overlaps fixed. Making another pass...
# 22
# 200
# 107 overlaps fixed. Making another pass...
# 23
# 200
# 98 overlaps fixed. Making another pass...
# 24
# 200
# 105 overlaps fixed. Making another pass...
# 25
# 200
# 104 overlaps fixed. Making another pass...
# 26
# 200
# 86 overlaps fixed. Making another pass...
# 27
# 200
# 98 overlaps fixed. Making another pass...
# 28
# 200
# 81 overlaps fixed. Making another pass...
# 29
# 200
# 92 overlaps fixed. Making another pass...
# 30
# 200
# 72 overlaps fixed. Making another pass...
# 31
# 200
# 96 overlaps fixed. Making another pass...
# 32
# 200
# 118 overlaps fixed. Making another pass...
# 33
# 200
# 90 overlaps fixed. Making another pass...
# 34
# 200
# 123 overlaps fixed. Making another pass...
# 35
# 200
# 113 overlaps fixed. Making another pass...
# 36
# 200
# 110 overlaps fixed. Making another pass...
# 37
# 200
# 100 overlaps fixed. Making another pass...
# 38
# 200
# 82 overlaps fixed. Making another pass...
# 39
# 200
# 76 overlaps fixed. Making another pass...
# 40
# 200
# 80 overlaps fixed. Making another pass...
# 41
# 200
# 108 overlaps fixed. Making another pass...
# 42
# 200
# 102 overlaps fixed. Making another pass...
# 43
# 200
# 90 overlaps fixed. Making another pass...
# 44
# 200
# 98 overlaps fixed. Making another pass...
# 45
# 200
# 94 overlaps fixed. Making another pass...
# 46
# 200
# 107 overlaps fixed. Making another pass...
# 47
# 200
# 102 overlaps fixed. Making another pass...
# 48
# 200
# 125 overlaps fixed. Making another pass...
# 49
# 200
# 96 overlaps fixed. Making another pass...
# 50
# 200
# 88 overlaps fixed. Making another pass...
# 51
# 200
# 77 overlaps fixed. Making another pass...
# 52
# 200
# 118 overlaps fixed. Making another pass...
# 53
# 200
# 105 overlaps fixed. Making another pass...
# 54
# 200
# 118 overlaps fixed. Making another pass...
# 55
# 200
# 86 overlaps fixed. Making another pass...
# 56
# 200
# 102 overlaps fixed. Making another pass...
# 57
# 200
# 84 overlaps fixed. Making another pass...
# 58
# 200
# 110 overlaps fixed. Making another pass...
# 59
# 200
# 93 overlaps fixed. Making another pass...
# 60
# 200
# 88 overlaps fixed. Making another pass...
# 61
# 200
# 102 overlaps fixed. Making another pass...
# 62
# 200
# 109 overlaps fixed. Making another pass...
# 63
# 200
# 93 overlaps fixed. Making another pass...
# 64
# 200
# 88 overlaps fixed. Making another pass...
# 65
# 200
# 112 overlaps fixed. Making another pass...
# 66
# 200
# 86 overlaps fixed. Making another pass...
# 67
# 200
# 123 overlaps fixed. Making another pass...
# 68
# 200
# 121 overlaps fixed. Making another pass...
# 69
# 200
# 104 overlaps fixed. Making another pass...
# 70
# 200
# 107 overlaps fixed. Making another pass...
# 71
# 200
# 116 overlaps fixed. Making another pass...
# 72
# 200
# 108 overlaps fixed. Making another pass...
# 73
# 200
# 76 overlaps fixed. Making another pass...
# 74
# 200
# 83 overlaps fixed. Making another pass...
# 75
# 200
# 98 overlaps fixed. Making another pass...
# 76
# 200
# 92 overlaps fixed. Making another pass...
# 77
# 200
# 117 overlaps fixed. Making another pass...
# 78
# 200
# 132 overlaps fixed. Making another pass...
# 79
# 200
# 103 overlaps fixed. Making another pass...
# 80
# 200
# 94 overlaps fixed. Making another pass...
# 81
# 200
# 91 overlaps fixed. Making another pass...
# 82
# 200
# 99 overlaps fixed. Making another pass...
# 83
# 200
# 94 overlaps fixed. Making another pass...
# 84
# 200
# 99 overlaps fixed. Making another pass...
# 85
# 200
# 94 overlaps fixed. Making another pass...
# 86
# 200
# 75 overlaps fixed. Making another pass...
# 87
# 200
# 85 overlaps fixed. Making another pass...
# 88
# 200
# 91 overlaps fixed. Making another pass...
# 89
# 200
# 89 overlaps fixed. Making another pass...
# 90
# 200
# 91 overlaps fixed. Making another pass...
# 91
# 200
# 82 overlaps fixed. Making another pass...
# 92
# 200
# 79 overlaps fixed. Making another pass...
# 93
# 200
# 101 overlaps fixed. Making another pass...
# 94
# 200
# 86 overlaps fixed. Making another pass...
# 95
# 200
# 128 overlaps fixed. Making another pass...
# 96
# 200
# 105 overlaps fixed. Making another pass...
# 97
# 200
# 90 overlaps fixed. Making another pass...
# 98
# 200
# 106 overlaps fixed. Making another pass...
# 99
# 200
# 117 overlaps fixed. Making another pass...
# 100
# 200
# 129 overlaps fixed. Making another pass...
# 101
# 200
# 107 overlaps fixed. Making another pass...
# 102
# 200
# 84 overlaps fixed. Making another pass...
# 103
# 200
# 92 overlaps fixed. Making another pass...
# 104
# 200
# 73 overlaps fixed. Making another pass...
# 105
# 200
# 72 overlaps fixed. Making another pass...
# 106
# 200
# 71 overlaps fixed. Making another pass...
# 107
# 200
# 117 overlaps fixed. Making another pass...
# 108
# 200
# 87 overlaps fixed. Making another pass...
# 109
# 200
# 109 overlaps fixed. Making another pass...
# 110
# 200
# 123 overlaps fixed. Making another pass...
# 111
# 200
# 106 overlaps fixed. Making another pass...
# 112
# 200
# 107 overlaps fixed. Making another pass...
# 113
# 200
# 116 overlaps fixed. Making another pass...
# 114
# 200
# 112 overlaps fixed. Making another pass...
# 115
# 200
# 119 overlaps fixed. Making another pass...
# 116
# 200
# 107 overlaps fixed. Making another pass...
# 117
# 200
# 140 overlaps fixed. Making another pass...
# 118
# 200
# 121 overlaps fixed. Making another pass...
# 119
# 200
# 138 overlaps fixed. Making another pass...
# 120
# 200
# 121 overlaps fixed. Making another pass...
# 121
# 200
# 95 overlaps fixed. Making another pass...
# 122
# 200
# 95 overlaps fixed. Making another pass...
# 123
# 200
# 94 overlaps fixed. Making another pass...
# 124
# 200
# 78 overlaps fixed. Making another pass...
# 125
# 200
# 100 overlaps fixed. Making another pass...
# 126
# 200
# 67 overlaps fixed. Making another pass...
# 127
# 200
# 83 overlaps fixed. Making another pass...
# 128
# 200
# 99 overlaps fixed. Making another pass...
# 129
# 200
# 135 overlaps fixed. Making another pass...
# 130
# 200
# 106 overlaps fixed. Making another pass...
# 131
# 200
# 114 overlaps fixed. Making another pass...
# 132
# 200
# 90 overlaps fixed. Making another pass...
# 133
# 200
# 109 overlaps fixed. Making another pass...
# 134
# 200
# 102 overlaps fixed. Making another pass...
# 135
# 200
# 117 overlaps fixed. Making another pass...
# 136
# 200
# 93 overlaps fixed. Making another pass...
# 137
# 200
# 140 overlaps fixed. Making another pass...
# 138
# 200
# 109 overlaps fixed. Making another pass...
# 139
# 200
# 98 overlaps fixed. Making another pass...
# 140
# 200
# 98 overlaps fixed. Making another pass...
# 141
# 200
# 137 overlaps fixed. Making another pass...
# 142
# 200
# 110 overlaps fixed. Making another pass...
# 143
# 200
# 109 overlaps fixed. Making another pass...
# 144
# 200
# 120 overlaps fixed. Making another pass...
# 145
# 200
# 132 overlaps fixed. Making another pass...
# 146
# 200
# 122 overlaps fixed. Making another pass...
# 147
# 200
# 119 overlaps fixed. Making another pass...
# 148
# 200
# 94 overlaps fixed. Making another pass...
# 149
# 200
# 111 overlaps fixed. Making another pass...
# 150
# 200
# 96 overlaps fixed. Making another pass...
# 151
# 200
# 170 overlaps fixed. Making another pass...
# 152
# 200
# 142 overlaps fixed. Making another pass...
# 153
# 200
# 120 overlaps fixed. Making another pass...
# 154
# 200
# 109 overlaps fixed. Making another pass...
# 155
# 200
# 103 overlaps fixed. Making another pass...
# 156
# 200
# 117 overlaps fixed. Making another pass...
# 157
# 200
# 130 overlaps fixed. Making another pass...
# 158
# 200
# 102 overlaps fixed. Making another pass...
# 159
# 200
# 96 overlaps fixed. Making another pass...
# 160
# 200
# 109 overlaps fixed. Making another pass...
# 161
# 200
# 106 overlaps fixed. Making another pass...
# 162
# 200
# 111 overlaps fixed. Making another pass...
# 163
# 200
# 105 overlaps fixed. Making another pass...
# 164
# 200
# 129 overlaps fixed. Making another pass...
# 165
# 200
# 102 overlaps fixed. Making another pass...
# 166
# 200
# 112 overlaps fixed. Making another pass...
# 167
# 200
# 117 overlaps fixed. Making another pass...
# 168
# 200
# 102 overlaps fixed. Making another pass...
# 169
# 200
# 92 overlaps fixed. Making another pass...
# 170
# 200
# 111 overlaps fixed. Making another pass...
# 171
# 200
# 136 overlaps fixed. Making another pass...
# 172
# 200
# 117 overlaps fixed. Making another pass...
# 173
# 200
# 121 overlaps fixed. Making another pass...
# 174
# 200
# 103 overlaps fixed. Making another pass...
# 175
# 200
# 104 overlaps fixed. Making another pass...
# 176
# 200
# 117 overlaps fixed. Making another pass...
# 177
# 200
# 110 overlaps fixed. Making another pass...
# 178
# 200
# 163 overlaps fixed. Making another pass...
# 179
# 200
# 174 overlaps fixed. Making another pass...
# 180
# 200
# 138 overlaps fixed. Making another pass...
# 181
# 200
# 142 overlaps fixed. Making another pass...
# 182
# 200
# 123 overlaps fixed. Making another pass...
# 183
# 200
# 121 overlaps fixed. Making another pass...
# 184
# 200
# 149 overlaps fixed. Making another pass...
# 185
# 200
# 129 overlaps fixed. Making another pass...
# 186
# 200
# 132 overlaps fixed. Making another pass...
# 187
# 200
# 134 overlaps fixed. Making another pass...
# 188
# 200
# 99 overlaps fixed. Making another pass...
# 189
# 200
# 104 overlaps fixed. Making another pass...
# 190
# 200
# 101 overlaps fixed. Making another pass...
# 191
# 200
# 88 overlaps fixed. Making another pass...
# 192
# 200
# 100 overlaps fixed. Making another pass...
# 193
# 200
# 81 overlaps fixed. Making another pass...
# 194
# 200
# 96 overlaps fixed. Making another pass...
# 195
# 200
# 95 overlaps fixed. Making another pass...
# 196
# 200
# 94 overlaps fixed. Making another pass...
# 197
# 200
# 104 overlaps fixed. Making another pass...
# 198
# 200
# 81 overlaps fixed. Making another pass...
# 199
# 200
# 102 overlaps fixed. Making another pass...
# 200
# 200
# 89
# Excessive output truncated after 524289 bytes.
#  overlaps fixed. Making another pass...
# 201
# 200
# 336 overlaps fixed. Making another pass...
# 1
# 200
# 162 overlaps fixed. Making another pass...
# 2
# 200
# 147 overlaps fixed. Making another pass...
# 3
# 200
# 171 overlaps fixed. Making another pass...

# %% [markdown]
# Run an ensemble of Langevin equations:

# %%
@time langevinEnsemble = Theorist.runLangevinSims(5000, arenaParams);
# Out:
# Energy: 0.0002
# 190.094087 seconds (2.87 G allocations: 44.528 GiB, 53.29% gc time)

# %% [markdown]
# ### Analysis

# %% [markdown]
# Speed distributions:
#
# For a well mixed population the particle speeds are predicted to be Rayleigh distributed with shape parameter $\sigma = \sqrt{E}$ where $E$ is the average particle energie.

# %%
evolveTime = arenaParams["evolveTime"]
speedPar_t_id = BParts.speedCalc(vel_t_dim_id)
speedLan_t_id = Theorist.speedCalc(langevinEnsemble, 1:evolveTime)
rDistPred = Rayleigh( sqrt(thermVals["E"]) );

# %%
speedMeanPar = mean(speedPar_t_id[500:end,:])
speedMeanLan = mean(speedLan_t_id)
speedMeanTheory = √(thermVals["E"])*sqrt(π/2)

println(speedMeanLan)
println(speedMeanPar)
println(speedMeanTheory)
# Out:
# 0.017701000294274332
# 0.017719561309263103
# 0.017724538509055157

# %%
p1 =
histogram(vec(speedPar_t_id[2000:end,:,:]), bins=100, normalize=true, label="particle simulation", 
    size=(450,300), dpi=100, linewidth=2)
histogram!(vec(speedLan_t_id), bins=100, normalize=true, 
    label="Langevin simulation",
    linewidth=2,
    linestyle=:dash)
plot!(range(0,0.10, length=100), pdf.(rDistPred, range(0,0.10, length=100)), 
    linestyle=:dashdot, linewidth=2, label="Rayleigh distribution")
xlims!(0,0.06)
xlabel!("speed")
ylabel!("distribution")
display(p1)

# savefig(p1, "../figures/fixedDensity_speedDist.pdf")

# %% [markdown]
# The velocity autocorrelation is expected to be described by
# \begin{equation}
#     \left< v(t)v(t+\tau) \right> = 2E e^{-\gamma \tau}
# \end{equation}
# where $\gamma$ is determined by the density through the mean free path $l$:
# \begin{equation}
#     \gamma = \frac{\sqrt{E}}{l} \sqrt{ \frac{\pi}{2} }
# \end{equation}
# which in turn is determined by the particle density $n$:
# \begin{equation}
#     l = \frac{1}{\sqrt{2}\sigma n}
# \end{equation}
# As such this is a good test to check whether a test particle's movement can in fact be modeled by a density coupled Brownian motion.

# %%
corrTime = 200
timesCorrL_t, vCorrLan_t = Theorist.velCorrelation(langevinEnsemble, (1,corrTime), steps=corrTime);
# timesCorrP_t, vCorrPar_t = BParts.velocityAutocorrelation(vel_t_dim_id, (waitTime, waitTime+corrTime), arenaParams["timeStep"]);
timesCorrP_t, vCorrPar_t = BParts.velocityAutocorrelation(vel_t_dim_id, (waitTime, waitTime+corrTime), 1);
vCorrPred_t = map( t->2*thermVals["E"]*exp(-thermVals["γ"]*t), 0:corrTime-1 );

# %%
title = "ρ = "*string(round(thermVals["ρ"],digits=2))
p2 = plot(timesCorrP_t, vCorrPar_t, label="particle simulation", 
    size=(450,300),
    linewidth=2,
    titlefontsize=10,
    legendfontsize=9,
    dpi=100)
plot!(timesCorrL_t, vCorrLan_t, 
    linewidth=2,
    linestyle=:dash,
    label="Langevin simulation")
plot!(timesCorrL_t, vCorrPred_t,
    linewidth=2,
    linestyle=:dashdot,
    label="analytical prediction")
xlabel!(L"\tau")
ylabel!(L"\left< v(t)v(t+\tau) \right>")
title!(title)
display(p2)

savefig(p2, "../Figures/fixedDensity_velautocorr_rho"*string(round(thermVals["ρ"],digits=2))*".pdf")

# %% [markdown]
# Mean squared displacement:

# %%
msdTimes = (waitTime, evolveTime)
timesLMSD_t, msdLan_t = Theorist.msd(langevinEnsemble, arenaParams,  msdTimes);
timesPMSD_t = msdTimes[1]:msdTimes[2]
msdPar_t = BParts.meanSquaredDisplacement(pos_t_dim_id, msdTimes);

# %%
p2 = plot(timesPMSD_t, msdPar_t, label="particle simulation", linewidth=2, 
    legend=:bottomright, size=(400,300))
plot!(timesLMSD_t, msdLan_t, label="Langevin simulation", linewidth=2, linestyle=:dash)
xlabel!("t")
ylabel!("msd")
display(p2)

savefig(p2, "../Figures/fixedDensity_msd.pdf")

# %% [markdown]
# ## MSD for different densities
# As the density of the system increases, cells undergo more collisions, thus we predict the MSD to decrease as the density increase. Note that becuase the cells are spatially constrained the MSD must converge to a maximum value determined by the system's size.

# %%
sDensity(n0, r, V) = n0*π*r^2 / V
# Out:
# sDensity (generic function with 1 method)

# %%
nSims = 50

arenaParams2 = 
    Dict(
        "n0"=> 1,
        "evolveTime"=> 1500,
        "timeStep"=> 0.2,
        "bounds"=>((0.,10.),(0.,10.)), 
        "radius"=>0.08, 
        "speed"=>0.03
    )
extendParams!(arenaParams2)

waitTime = 500
evolveTime = arenaParams2["evolveTime"]

# display(arenaParams2)
n0_sim = [100, 200, 400, 800]
dens_sim = sDensity.(n0_sim, arenaParams2["radius"], arenaParams2["volume"])
# Out:
# 4-element Array{Float64,1}:
#  0.02010619298297468
#  0.04021238596594936
#  0.08042477193189872
#  0.16084954386379743

# %%
# ===== Multiple Parameter sets =====
params_dens = Array{Dict}(undef, length(n0_sim))
for (i,n0) in enumerate(n0_sim)
    params_dens[i] = copy(arenaParams2)
    params_dens[i]["n0"] = n0
    extendParams!(params_dens[i])
end
# Out:
# 4-element Array{Dict,1}:
#  Dict{String,Any}("volume" => 100.0,"evolveTime" => 1500,"speed" => 0.03,"radius" => 0.08,"timeStep" => 0.2,"bounds" => ((0.0, 10.0), (0.0, 10.0)),"bperiod" => [10.0, 10.0],"n0" => 100)
#  Dict{String,Any}("volume" => 100.0,"evolveTime" => 1500,"speed" => 0.03,"radius" => 0.08,"timeStep" => 0.2,"bounds" => ((0.0, 10.0), (0.0, 10.0)),"bperiod" => [10.0, 10.0],"n0" => 200)
#  Dict{String,Any}("volume" => 100.0,"evolveTime" => 1500,"speed" => 0.03,"radius" => 0.08,"timeStep" => 0.2,"bounds" => ((0.0, 10.0), (0.0, 10.0)),"bperiod" => [10.0, 10.0],"n0" => 400)
#  Dict{String,Any}("volume" => 100.0,"evolveTime" => 1500,"speed" => 0.03,"radius" => 0.08,"timeStep" => 0.2,"bounds" => ((0.0, 10.0), (0.0, 10.0)),"bperiod" => [10.0, 10.0],"n0" => 800)

# %%
# ===== Multiple Particle simulations =====

pos_Dens_Sim_t_dim_id = Array{Array{Array{Union{Float64, Missing},3}}}(undef, length(n0_sim))
@showprogress for (d, n0) in enumerate(n0_sim)
    
    arenaParams2["n0"] = n0
    pos_Sim = Array{Array{Union{Float64, Missing},3}}(undef, nSims)
    for i in 1:nSims
        succes = false
        while !succes 
            # try/catch construction in case boundserror occurs
            try
                _, posSim_t_dim_id, __, ___ = 
                    BParts.randArenaEvolve(arenaParams2["n0"], 
                        arenaParams2["evolveTime"], 
                        arenaParams2["timeStep"], 
                        arenaParams2;
                        progress=false, verbose=false)
                pos_Sim[i] = posSim_t_dim_id
    #             println("sim: ", i)
            catch e
               continue 
            end
            succes = true
        end
    end
    pos_Dens_Sim_t_dim_id[d] = pos_Sim
end
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 1:34:02

# %%
# ===== Multiple Langevin simulations =====

lEnsSim_Dens = []

for (d, n0) in enumerate(n0_sim)
    arenaParams2["n0"] = n0
    extendParams!(arenaParams2)
    @time langevinEnsembleSim = Theorist.runLangevinSims(5000, arenaParams2)
    push!(lEnsSim_Dens, langevinEnsembleSim)
    
end
# Out:
# Energy: 0.00045
#  83.467156 seconds (1.34 G allocations: 20.947 GiB, 43.40% gc time)
# Energy: 0.00045
#  96.412943 seconds (1.34 G allocations: 20.947 GiB, 49.89% gc time)
# Energy: 0.00045
# 130.860312 seconds (1.34 G allocations: 20.947 GiB, 64.92% gc time)
# Energy: 0.00045
# 350.393189 seconds (1.43 G allocations: 22.288 GiB, 86.01% gc time)

# %%
# ===== MSD Particle simulations =====

msdTimes = (waitTime, evolveTime)
timesPMSD_t = msdTimes[1]:msdTimes[2]

msd_Dens_t = Array{Float64}[]
for j in 1:length(n0_sim)
    
    msd_Sim = Array{Array{Float64}}(undef, nSims)
    @showprogress for i in 1:nSims
        msd_Sim[i] = BParts.meanSquaredDisplacement(pos_Dens_Sim_t_dim_id[j][i], msdTimes)
    end
    
    msdAv_t = Array{Float64, 1}(undef, length(timesPMSD_t))
    for i in 1:length(timesPMSD_t)
        msdAv_t[i] = mean([ msd_tt[i] for msd_tt in msd_Sim ])
    end
    push!(msd_Dens_t, msdAv_t)
end
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:01
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:03
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:07
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:15

# %%
# ===== MSD theory =====

function msdTheory(t, E, γ)
    4 * (E / γ)*(  t - ( 1 - exp(-γ*t) )/γ  )
end

msdTheory_t = (t -> msdTheory(t, thermVals["E"], thermVals["γ"])).(timesPMSD_t.-timesPMSD_t[1]);

# %%
# ===== MSD Langevin simulations =====

msdL_Dens_t = Array{Float64}[]
msdLT_Dens_t = Array{Float64}[]
@showprogress for j in 1:length(n0_sim)
    
    @time timesLMSD_t, msdLan_t = Theorist.msd(lEnsSim_Dens[j], arenaParams2,  msdTimes)
    push!(msdL_Dens_t, msdLan_t)
    
    thermVals2 = Theorist.thermalValues(params_dens[j])
    msdLTheory_t = (t -> msdTheory(t, thermVals2["E"], thermVals2["γ"])).(timesPMSD_t.-timesPMSD_t[1]);
    push!(msdLT_Dens_t, msdLTheory_t)
    
end
# Out:
# Progress:  25%|██████████▎                              |  ETA: 0:01:43
#  34.471371 seconds (44.79 M allocations: 2.644 GiB, 79.35% gc time)
# Progress:  50%|████████████████████▌                    |  ETA: 0:01:32
#  57.953414 seconds (44.79 M allocations: 2.644 GiB, 86.81% gc time)
# Progress:  75%|██████████████████████████████▊          |  ETA: 0:00:50
#  57.927971 seconds (44.79 M allocations: 2.644 GiB, 87.55% gc time)
# Progress: 100%|█████████████████████████████████████████| Time: 0:02:57
#  27.532570 seconds (44.79 M allocations: 2.644 GiB, 79.33% gc time)

# %%
msdLT_Dens_t = Array{Float64}[]
for j in 1:length(n0_sim)
    
    thermVals2 = Theorist.thermalValues(params_dens[j])
    msdLTheory_t = (t -> msdTheory(t, thermVals2["E"], thermVals2["γ"])).(timesPMSD_t.-timesPMSD_t[1]);
    push!(msdLT_Dens_t, msdLTheory_t)
    
end

# %%
p2 = plot(timesPMSD_t.-timesPMSD_t[1], msd_Dens_t[1], label="Particle sim; dens="*string(round(dens_sim[1], digits=2)), linewidth=2, 
    legend=:topleft, size=(500,300), color=1)
plot!(timesPMSD_t.-timesPMSD_t[1], msdL_Dens_t[1], label="Langevin sim", linewidth=2, linestyle=:dash, color=1)
# plot!(timesPMSD_t, msdLT_Dens_t[1], label="Langevin Integral", linewidth=2, linestyle=:dashdot, color=1)
for i in 2:length(n0_sim)
    plot!(timesPMSD_t.-timesPMSD_t[1], msd_Dens_t[i], label="Particle sim; dens="*string(round(dens_sim[i], digits=2)), linewidth=2, color=i)
    plot!(timesPMSD_t.-timesPMSD_t[1], msdL_Dens_t[i], label="Langevin sim", linewidth=2, linestyle=:dash, color=i)
#     plot!(timesPMSD_t, msdLT_Dens_t[i], label="Langevin integral", linewidth=2, linestyle=:dashdot, color=i)
end
xlabel!("t")
ylabel!("msd")
display(p2)

savefig(p2, "../Figures/multFixedDensity_msd_s"*string(arenaParams2["speed"])*".pdf")

# %%
p2 = plot((timesPMSD_t.-timesPMSD_t[1])[100:end], msd_Dens_t[1][100:end].-msd_Dens_t[1][100], label="Particle sim; dens="*string(round(dens_sim[1], digits=2)), linewidth=2, 
    legend=:topleft, size=(500,300), color=1)
plot!((timesPMSD_t.-timesPMSD_t[1])[100:end], msdL_Dens_t[1][100:end].-msdL_Dens_t[1][100], label="Langevin sim", linewidth=2, linestyle=:dash, color=1)
# plot!(timesPMSD_t, msdLT_Dens_t[1], label="Langevin Integral", linewidth=2, linestyle=:dashdot, color=1)
for i in 2:length(n0_sim)
    plot!((timesPMSD_t.-timesPMSD_t[1])[100:end], msd_Dens_t[i][100:end].-msd_Dens_t[i][100], label="Particle sim; dens="*string(round(dens_sim[i], digits=2)), linewidth=2, color=i)
    plot!((timesPMSD_t.-timesPMSD_t[1])[100:end], msdL_Dens_t[i][100:end].-msdL_Dens_t[i][100], label="Langevin sim", linewidth=2, linestyle=:dash, color=i)
#     plot!(timesPMSD_t, msdLT_Dens_t[i], label="Langevin integral", linewidth=2, linestyle=:dashdot, color=i)
end
xlabel!("t")
ylabel!("msd")
display(p2)
