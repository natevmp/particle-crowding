# %% [markdown]
# # Particle simulation vs Langevin model

# %%
using ProgressMeter
using Revise
using JLD2

# %%
include("../src/bmparticles.jl")
include("../src/bmtheory.jl")
using .BParts
using .Theorist
using DifferentialEquations, Distributions

# %% [markdown]
# ## Growing population

# %% [markdown]
# ### Parameters

# %%
using Plots
# plotly()
gr()
# plotlyjs()
# pyplot()
# Out:
# Plots.GRBackend()

# %%
using LaTeXStrings

# %%
function extendParams!(arenaParams::Dict)
    bounds = arenaParams["bounds"]
    arenaParams["volume"] = abs(bounds[1][2]-bounds[1][1])*abs(bounds[2][2]-bounds[2][1])
    arenaParams["bperiod"] = [abs(bounds[1][2]-bounds[1][1]), abs(bounds[2][2]-bounds[2][1])]
    arenaParams["E"] = arenaParams["speed"]^2/2
end
# Out:
# extendParams! (generic function with 1 method)

# %%
arenaParams = 
    Dict(
        "n0"=>100,
        "evolveTime"=>4500,
        "bounds"=>((0.,10.),(0.,10.)), 
        "radius"=>0.08, 
        "speed"=>0.02,
        "timeStep"=> 0.1
    )

growthParams =
    Dict(
        "ρ"=> 0.005,
        "k"=> 1000,
        "randGrowth"=> false,
        "waitTime"=> 500
    )

extendParams!(arenaParams)

display(arenaParams)
display(growthParams)

function fillDensity(arenaParams, growthParams)  
    xperiod = abs(arenaParams["bounds"][1][2] - arenaParams["bounds"][1][1])
    yperiod = abs(arenaParams["bounds"][2][2] - arenaParams["bounds"][2][1])
    n0 = arenaParams["n0"]
    nT = growthParams["k"]
    r = arenaParams["radius"]
    V = xperiod*yperiod
    fillDens0 = n0*π*r^2 / V
    fillDensT = nT*π*r^2 / V
    return fillDens0, fillDensT
end

volumeDens(n, r, V) = n*π*r^2/V

timeSteps = arenaParams["timeStep"]:arenaParams["timeStep"]:arenaParams["evolveTime"]

println("t0 density: ", fillDensity(arenaParams, growthParams)[1])
println("t0 density: ", fillDensity(arenaParams, growthParams)[2])
# Out:
# Dict{String,Any} with 9 entries:
#   "volume"     => 100.0
#   "evolveTime" => 4500
#   "speed"      => 0.02
#   "radius"     => 0.08
#   "timeStep"   => 0.1
#   "E"          => 0.0002
#   "bounds"     => ((0.0, 10.0), (0.0, 10.0))
#   "bperiod"    => [10.0, 10.0]
#   "n0"         => 100
# Dict{String,Real} with 4 entries:
#   "waitTime"   => 500
#   "k"          => 1000
#   "ρ"          => 0.001
#   "randGrowth" => false
# t0 density: 0.02010619298297468
# t0 density: 0.20106192982974677

# %% [markdown]
# ### Logistic Growth
#
# The number of cells in the system increases according to the logistic growth function:
# \begin{equation}
# n(t) = \frac{k}{ 1 + \frac{k-n_0}{n_0}e^{-\rho t}}
# \end{equation}

# %% [markdown]
# ### Mean Free Path and Friction

# %%
nCells_t = Theorist.logisticGrowth.(0:(arenaParams["evolveTime"]-growthParams["waitTime"]-1), 
            growthParams["ρ"], growthParams["k"], arenaParams["n0"]);

mfpTheory_t = (x -> Theorist.meanFreePath(x, 4*arenaParams["radius"])).(nCells_t);
frictionTheory_t = ( l -> Theorist.friction(l, arenaParams["E"]) ).(mfpTheory_t);

# %%
f2 = plot(0:(arenaParams["evolveTime"]-growthParams["waitTime"]-1), mfpTheory_t,
        label="Theoretical prediction",
        linewidth=2,
        legend=:topright,
        size=(450,300))
xlabel!("time")
ylabel!("mean free path")
display(f2)

savefig(f2, "../Figures/rho"*string(growthParams["ρ"])*"mfp_time.pdf")

f3 = plot(0:(arenaParams["evolveTime"]-growthParams["waitTime"]-1), 
            arenaParams["speed"]*frictionTheory_t,
        label="Theoretical prediction",
        linewidth=2,
        legend=:bottomright,
        size=(450,300))
xlabel!("time")
ylabel!("friction")
display(f3)

savefig(f3, "../Figures/rho"*string(growthParams["ρ"])*"friction_time.pdf")

f4 = plot(0:(arenaParams["evolveTime"]-growthParams["waitTime"]-1),
            1 ./ (arenaParams["speed"]*frictionTheory_t),
        label="Theoretical prediction",
        linewidth=2,
#         legend=:bottomright,
        size=(450,300))
xlabel!("time")
ylabel!("friction time (mass / friction)")
display(f4)

savefig(f4, "../Figures/rho"*string(growthParams["ρ"])*"frictionTime_time.pdf")

# %% [markdown]
# Run Langevin simulations:

# %%
@time langevinEnsemble = Theorist.runLangevinSims(5000, arenaParams, growthParams);
# Out:
# Energy: 0.0002
# 218.221833 seconds (5.35 G allocations: 90.651 GiB, 13.25% gc time)

# %% [markdown]
# Run a particle simulation:

# %%
# @time arena, pos_t_dim_id, vel_t_dim_id, cells_T_ID, times_t = 
#         BParts.randArenaEvolve(
#             arenaParams["n0"], 
#             arenaParams["evolveTime"],
#             arenaParams["timeStep"],
#             arenaParams,
#             growthParams,
#             verbose=true);

# %%
# msdPart0_t = BParts.meanSquaredDisplacement(pos_t_dim_id, msdTimes)

# %%
# f1 = plot(0:(arenaParams["evolveTime"]-1-growthParams["waitTime"]), 
#         volumeDens.(
#             Theorist.logisticGrowth.(0:(arenaParams["evolveTime"]-growthParams["waitTime"]-1), 
#             growthParams["ρ"], growthParams["k"], arenaParams["n0"]),
#             arenaParams["radius"],
#             arenaParams["volume"]
#         ),
#         label="growth function",
#         linewidth=2,
#         size=(450,300),
#         legend=:topleft)
# plot!(times_t .- growthParams["waitTime"], 
#     volumeDens.(
#         BParts.nCellsTime(cells_T_ID)[1:end],     
#         arenaParams["radius"],
#         arenaParams["volume"]
#     ),
#     label="particle simulation",
#     linewidth=2,
#     linestyle=:dash)
# xlabel!("time")
# ylabel!("occupied surface density")
# xlims!(0,arenaParams["evolveTime"]-growthParams["waitTime"])
# display(f1)

# savefig(f1, "../Figures/rho"*string(growthParams["ρ"])*"surfaceDensity_time.pdf")

# %% [markdown]
# Ensemble of particle simulations:

# %%
nSims = 50

pos_Sim = Array{Array{Union{Float64, Missing},3}}(undef, nSims)
@showprogress for i in 1:nSims
    succes = false
    while !succes 
        # try/catch construction in case boundserror occurs
        try
            @time _, posSim_t_dim_id, __, ___ = 
                BParts.randArenaEvolve(
                        arenaParams["n0"],
                        arenaParams["evolveTime"], 
                        arenaParams["timeStep"],
                        arenaParams,
                        growthParams,
                        progress=false,
                        verbose=true);
            pos_Sim[i] = posSim_t_dim_id
#             println("sim: ", i)
        catch e
#             println("fail")
            continue
        end
        succes = true
    end
end
# Out:
# Building arena...
# 0 overlaps found.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 152.144100 seconds (237.92 M allocations: 10.284 GiB, 9.38% gc time)
# Progress:   2%|▉                                        |  ETA: 2:04:47
# Building arena...
# 2 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 169.966939 seconds (221.43 M allocations: 9.409 GiB, 10.96% gc time)
# Progress:   4%|█▋                                       |  ETA: 2:09:25
# Building arena...
# 6 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 186.378489 seconds (220.96 M allocations: 9.391 GiB, 19.65% gc time)
# Progress:   6%|██▌                                      |  ETA: 2:13:12
# Building arena...
# 6 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 160.444136 seconds (221.43 M allocations: 9.407 GiB, 12.19% gc time)
# Progress:   8%|███▎                                     |  ETA: 2:08:34
# Building arena...
# 7 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 193.840501 seconds (220.11 M allocations: 9.354 GiB, 11.21% gc time)
# Progress:  10%|████▏                                    |  ETA: 2:09:43
# Building arena...
# 2 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 175.943442 seconds (220.53 M allocations: 9.373 GiB, 11.92% gc time)
# Progress:  12%|████▉                                    |  ETA: 2:07:13
# Building arena...
# 3 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# anomalous collision time 0.8821065919370829 found in time step0.1
# anomalous collision time 11.958002914883112 found in time step0.1
# anomalous collision time 0.9692146245767002 found in time step0.1
# anomalous collision time 12.619675914658416 found in time step0.1
# anomalous collision time 1.6008470081898822 found in time step0.1
# anomalous collision time 12.654800306893714 found in time step0.1
# anomalous collision time 11.204825321682005 found in time step0.1
# anomalous collision time 8.753207353942345 found in time step0.1
# anomalous collision time 7.531725572622388 found in time step0.1
# anomalous collision time 7.790263986683848 found in time step0.1
# anomalous collision time 12.654800306893708 found in time step0.1
# anomalous collision time 5.111469109212038 found in time step0.1
# anomalous collision time 2.666752763238162 found in time step0.1
# anomalous collision time 12.654800306893872 found in time step0.1
# anomalous collision time 12.654800306893954 found in time step0.1
# anomalous collision time 12.654800306894057 found in time step0.1
# anomalous collision time 6.8960046938598465 found in time step0.1
# anomalous collision time 2.3207060185981017 found in time step0.1
# anomalous collision time 2.0086914697739577 found in time step0.1
# anomalous collision time 12.654800306894076 found in time step0.1
# anomalous collision time 5.126775678477003 found in time step0.1
# anomalous collision time 1.4263489859279548 found in time step0.1
# anomalous collision time 4.529105803926049 found in time step0.1
# anomalous collision time 3.8978540846824776 found in time step0.1
# anomalous collision time 6.61340546941024 found in time step0.1
# anomalous collision time 2.320775555624454 found in time step0.1
# anomalous collision time 13.192049257822875 found in time step0.1
# anomalous collision time 13.192049257822907 found in time step0.1
# anomalous collision time 6.906800635912782 found in time step0.1
# anomalous collision time 5.241687284444352 found in time step0.1
# anomalous collision time 213.7555455139548 found in time step0.1
# anomalous collision time 0.8965913111449625 found in time step0.1
# anomalous collision time 259.7965563503358 found in time step0.1
# anomalous collision time 16.27828027129923 found in time step0.1
# Building arena...
# 4 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.759541 seconds (220.25 M allocations: 9.359 GiB, 4.78% gc time)
# Progress:  14%|█████▊                                   |  ETA: 2:14:11
# Building arena...
# 3 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 121.409341 seconds (220.27 M allocations: 9.362 GiB, 5.73% gc time)
# Progress:  16%|██████▌                                  |  ETA: 2:05:19
# Building arena...
# 4 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 122.077516
# Progress:  18%|███████▍                                 |  ETA: 1:58:01
#  seconds (220.53 M allocations: 9.373 GiB, 5.81% gc time)
# Building arena...
# 3 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.869503
# Progress:  20%|████████▎                                |  ETA: 1:51:41
#  seconds (220.09 M allocations: 9.354 GiB, 5.60% gc time)
# Building arena...
# 6 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.763676 seconds (220.30 M allocations: 9.364 GiB, 5.63% gc time)
# Progress:  22%|█████████                                |  ETA: 1:46:08
# Building arena...
# 6 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 121.245649
# Progress:  24%|█████████▉                               |  ETA: 1:41:12
#  seconds (219.90 M allocations: 9.348 GiB, 5.74% gc time)
# Building arena...
# 2 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 121.045578 seconds (220.57 M allocations: 9.373 GiB, 5.61% gc time)
# Progress:  26%|██████████▋                              |  ETA: 1:36:42
# Building arena...
# 3 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 121.411977 seconds (220.48 M allocations: 9.369 GiB, 5.64% gc time)
# Progress:  28%|███████████▌                             |  ETA: 1:32:35
# Building arena...
# 0 overlaps found.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 122.209943
# Progress:  30%|████████████▎                            |  ETA: 1:28:46
#  seconds (220.69 M allocations: 9.378 GiB, 5.72% gc time)
# Building arena...
# 4 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.603289
# Progress:  32%|█████████████▏                           |  ETA: 1:25:07
#  seconds (220.50 M allocations: 9.368 GiB, 5.56% gc time)
# Building arena...
# 2 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 121.867104 seconds (221.14 M allocations: 9.398 GiB, 5.54% gc time)
# Progress:  34%|██████████████                           |  ETA: 1:21:42
# Building arena...
# 4 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 121.649547 seconds (220.20 M allocations: 9.357 GiB, 5.74% gc time)
# Progress:  36%|██████████████▊                          |  ETA: 1:18:26
# Building arena...
# 4 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 123.128646
# Progress:  38%|███████████████▋                         |  ETA: 1:15:20
#  seconds (220.80 M allocations: 9.382 GiB, 6.03% gc time)
# Building arena...
# 3 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.526432
# Progress:  40%|████████████████▍                        |  ETA: 1:12:16
#  seconds (219.64 M allocations: 9.334 GiB, 5.55% gc time)
# Building arena...
# 4 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.715684
# Progress:  42%|█████████████████▎                       |  ETA: 1:09:19
#  seconds (219.70 M allocations: 9.339 GiB, 5.59% gc time)
# Building arena...
# 4 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 123.116845
# Progress:  44%|██████████████████                       |  ETA: 1:06:30
#  seconds (220.16 M allocations: 9.359 GiB, 6.73% gc time)
# Building arena...
# 2 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.074780 seconds (220.39 M allocations: 9.367 GiB, 5.69% gc time)
# Progress:  46%|██████████████████▉                      |  ETA: 1:03:41
# Building arena...
# 9 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.667412 seconds (221.34 M allocations: 9.404 GiB, 5.56% gc time)
# Progress:  48%|███████████████████▋                     |  ETA: 1:00:57
# Building arena...
# 7 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 121.734355 seconds (221.09 M allocations: 9.394 GiB, 5.75% gc time)
# Progress:  50%|████████████████████▌                    |  ETA: 0:58:18
# Building arena...
# 2 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.630084
# Progress:  52%|█████████████████████▍                   |  ETA: 0:55:40
#  seconds (219.67 M allocations: 9.338 GiB, 6.70% gc time)
# Building arena...
# 5 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 119.623940
# Progress:  54%|██████████████████████▏                  |  ETA: 0:53:04
#  seconds (220.94 M allocations: 9.386 GiB, 5.56% gc time)
# Building arena...
# 4 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 119.103824
# Progress:  56%|███████████████████████                  |  ETA: 0:50:31
#  seconds (220.21 M allocations: 9.359 GiB, 5.59% gc time)
# Building arena...
# 5 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.197666
# Progress:  58%|███████████████████████▊                 |  ETA: 0:48:00
#  seconds (219.70 M allocations: 9.339 GiB, 5.63% gc time)
# Building arena...
# 4 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 123.006262
# Progress:  60%|████████████████████████▋                |  ETA: 0:45:34
#  seconds (220.49 M allocations: 9.371 GiB, 6.86% gc time)
# Building arena...
# 5 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 119.580183
# Progress:  62%|█████████████████████████▍               |  ETA: 0:43:07
#  seconds (220.61 M allocations: 9.374 GiB, 5.53% gc time)
# Building arena...
# 5 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 119.134366 seconds (220.31 M allocations: 9.361 GiB, 5.58% gc time)
# Progress:  64%|██████████████████████████▎              |  ETA: 0:40:41
# Building arena...
# 8 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.909570
# Progress:  66%|███████████████████████████              |  ETA: 0:38:18
#  seconds (220.87 M allocations: 9.387 GiB, 5.57% gc time)
# Building arena...
# 3 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 119.530117
# Progress:  68%|███████████████████████████▉             |  ETA: 0:35:55
#  seconds (219.84 M allocations: 9.343 GiB, 5.58% gc time)
# Building arena...
# 7 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 122.197342
# Progress:  70%|████████████████████████████▊            |  ETA: 0:33:35
#  seconds (220.49 M allocations: 9.370 GiB, 6.71% gc time)
# Building arena...
# 4 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.217671
# Progress:  72%|█████████████████████████████▌           |  ETA: 0:31:15
#  seconds (220.89 M allocations: 9.386 GiB, 5.54% gc time)
# Building arena...
# 3 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.775547
# Progress:  74%|██████████████████████████████▍          |  ETA: 0:28:57
#  seconds (221.51 M allocations: 9.412 GiB, 5.63% gc time)
# Building arena...
# 1 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.166312
# Progress:  76%|███████████████████████████████▏         |  ETA: 0:26:39
#  seconds (221.42 M allocations: 9.410 GiB, 5.54% gc time)
# Building arena...
# 1 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 118.933130
# Progress:  78%|████████████████████████████████         |  ETA: 0:24:22
#  seconds (220.44 M allocations: 9.366 GiB, 5.57% gc time)
# Building arena...
# 4 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.021747
# Progress:  80%|████████████████████████████████▊        |  ETA: 0:22:06
#  seconds (220.44 M allocations: 9.370 GiB, 5.73% gc time)
# Building arena...
# 8 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 119.904694
# Progress:  82%|█████████████████████████████████▋       |  ETA: 0:19:50
#  seconds (220.45 M allocations: 9.369 GiB, 5.72% gc time)
# Building arena...
# 9 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.038035
# Progress:  84%|██████████████████████████████████▌      |  ETA: 0:17:36
#  seconds (220.42 M allocations: 9.366 GiB, 5.70% gc time)
# Building arena...
# 6 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 119.641454
# Progress:  86%|███████████████████████████████████▎     |  ETA: 0:15:22
#  seconds (220.38 M allocations: 9.366 GiB, 5.58% gc time)
# Building arena...
# 7 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 119.679427
# Progress:  88%|████████████████████████████████████▏    |  ETA: 0:13:09
#  seconds (220.71 M allocations: 9.378 GiB, 5.55% gc time)
# Building arena...
# 4 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 119.553351
# Progress:  90%|████████████████████████████████████▉    |  ETA: 0:10:56
#  seconds (220.88 M allocations: 9.386 GiB, 5.52% gc time)
# Building arena...
# 3 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 118.607466
# Progress:  92%|█████████████████████████████████████▊   |  ETA: 0:08:44
#  seconds (219.72 M allocations: 9.340 GiB, 5.56% gc time)
# Building arena...
# 8 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 119.525072
# Progress:  94%|██████████████████████████████████████▌  |  ETA: 0:06:32
#  seconds (220.94 M allocations: 9.389 GiB, 5.59% gc time)
# Building arena...
# 7 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 119.617920
# Progress:  96%|███████████████████████████████████████▍ |  ETA: 0:04:21
#  seconds (219.46 M allocations: 9.329 GiB, 5.62% gc time)
# Building arena...
# 8 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 120.345397 seconds (220.75 M allocations: 9.381 GiB, 5.53% gc time)
# Progress:  98%|████████████████████████████████████████▏|  ETA: 0:02:10
# Building arena...
# 3 overlaps found.
# Arena with 100 cells built.
# ::::: Initial total kinetic energy: 0.01999999999999999
# 121.002046
# Progress: 100%|█████████████████████████████████████████| Time: 1:48:21
#  seconds (220.99 M allocations: 9.390 GiB, 5.69% gc time)

# %% [markdown]
# ### Mean squared displacement

# %%
msdTimes = (growthParams["waitTime"]+1, arenaParams["evolveTime"])
# Out:
# (501, 4500)

# %%
@time msd_Sim_t = (p_t_dim_id -> BParts.meanSquaredDisplacement(p_t_dim_id, msdTimes)).(pos_Sim);
msdPart_t = Array{Float64, 1}(undef, msdTimes[2]-msdTimes[1]+1)
for i in 1:(msdTimes[2]-msdTimes[1]+1)
    msdPart_t[i] = mean([ msd_tt[i] for msd_tt in msd_Sim_t ])
end
# Out:
#  54.631124 seconds (346.00 M allocations: 38.668 GiB, 19.39% gc time)

# %%
length(msd_Sim_t[1])
# Out:
# 4000

# %%
timesMSD_t, msdLan_t = 
    Theorist.msd(
        langevinEnsemble, 
        arenaParams,
        (growthParams["waitTime"]+1, arenaParams["evolveTime"])
    )
# Out:
# (501:1:4500, [0.0, 0.0003972569853166552, 0.0015828697266494687, 0.0035526923010912983, 0.006298251345975956, 0.00981846612026256, 0.014109615246403829, 0.019173457307927168, 0.024990940507285717, 0.031555795875238817  …  119.91766544251624, 119.92589857953672, 119.93419841192835, 119.94194401254732, 119.95084641601635, 119.95912040468323, 119.96717857358, 119.97661451954882, 119.98775705693797, 119.99821252568134])

# %%
saveName = "growingPop_multSims_rho"*string(growthParams["ρ"])*".jld2"

@save saveName arenaParams growthParams msd_Sim_t msdPart_t msdLan_t

# %%
p2 = plot(1:msdTimes[2]-msdTimes[1], msdPart_t[2:end], label="particle simulation", legend=:bottomright, linewidth=2,
    size=(400,300), 
    dpi=140)
plot!(1:msdTimes[2]-msdTimes[1], msdLan_t[2:end], label="Langevin simulation", linestyle=:dash, linewidth=2)
xlabel!(L"t")
ylabel!(L"\left\langle x(t)^2 \right\rangle")
# title!(latexstring("\\rho="*string(growthParams["ρ"])))
display(p2)

# savefig(p2, "../Figures/rho"*string(growthParams["ρ"])*"msd_time.png")
savefig(p2, "../Figures/rho"*string(growthParams["ρ"])*"msd_time.pdf")

# %%
p2 = plot(1:msdTimes[2]-msdTimes[1], msdPart_t[2:end], label="particle simulation", legend=:bottomright, linewidth=2,
    xaxis=:log10, yaxis=:log10,
    size=(400,300), 
    dpi=140)
plot!(1:msdTimes[2]-msdTimes[1], msdLan_t[2:end], label="Langevin simulation", linestyle=:dash, linewidth=2)
xlabel!(L"t")
ylabel!(L"\left\langle x(t)^2 \right\rangle")
title!(latexstring("\\rho="*string(growthParams["ρ"])))
display(p2)

# savefig(p2, "../Figures/rho"*string(growthParams["ρ"])*"msdLoglog_time.png")
# savefig(p2, "../Figures/rho"*string(growthParams["ρ"])*"msdLoglog_time.pdf")

# %% [markdown]
# ## MSD linear regime

# %%
# msdTimes = (arenaParams["evolveTime"]-1000, arenaParams["evolveTime"])

# %%
# @time msd_Sim_t = (p_t_dim_id -> BParts.meanSquaredDisplacement(p_t_dim_id, msdTimes)).(pos_Sim);
# msdPart_t = Array{Float64, 1}(undef, msdTimes[2]-msdTimes[1]+1)
# for i in 1:(msdTimes[2]-msdTimes[1]+1)
#     msdPart_t[i] = mean([ msd_tt[i] for msd_tt in msd_Sim_t ])
# end

# %%
# length(msd_Sim_t[1])

# %%
# @time timesMSD_t, msdLan_t = 
#     Theorist.msd(
#         langevinEnsemble, 
#         arenaParams,
#         (arenaParams["evolveTime"]-1000, arenaParams["evolveTime"])
#     )
# # msdPar_t = BParts.meanSquaredDisplacement(pos_t_dim_id[1:msdTime,:,:], arenaParams["bperiod"]);

# %%
# p2 = plot(1:msdTimes[2]-msdTimes[1], msdPart_t[2:end], label="particle simulation", legend=:bottomright, linewidth=2,
#     size=(400,300), 
#     dpi=140)
# plot!(1:msdTimes[2]-msdTimes[1], msdLan_t[2:end], label="Langevin simulation", linestyle=:dash, linewidth=2)
# xlabel!(L"t")
# ylabel!(L"\left\langle x(t)^2 \right\rangle")
# # title!(latexstring("\\rho="*string(growthParams["ρ"])))
# display(p2)

# %%
# msdSingles_Sim = []

# for sim in 1:nSims
#     msd_t = BParts.meanSquaredDisplacement(pos_Sim[sim], msdTimes)
#     push!(msdSingles_Sim, msd_t)
# end

# %%
# p3 = plot(1:msdTimes[2]-msdTimes[1], msdLan_t[2:end], label="Langevin simulation", linestyle=:dash, linewidth=3,
#     legend=:topleft,
#     size=(500,300),
#     dpi=140)
# # plot!(1:msdTimes[2]-msdTimes[1], msdPart_t[2:end], label="particle simulation average", linestyle=:dashdot, linewidth=3)
# # plot!(1:msdTimes[2]-msdTimes[1], msdPart0_t[2:end])
# for s in 1:nSims
#     plot!(1:msdTimes[2]-msdTimes[1], msdSingles_Sim[s][2:end],
# #         label="particle simulation "*string(s),
#         label="")
# end
# xlabel!(L"t")
# ylabel!(L"\left\langle x(t)^2 \right\rangle")
# # title!(latexstring("\\rho="*string(growthParams["ρ"])))
# display(p3)

# # savefig(p2, "../Figures/rho"*string(growthParams["ρ"])*"msd_time.png")
# savefig(p3, "../Figures/rho"*string(growthParams["ρ"])*"msdSingles_time.pdf")

# %% [markdown]
# ## Position monitor

# %%
# pos_Sim[i] = posSim_t_dim_id
# cellID = 22

# p3 = plot(pos_Sim[4][:,1,1],pos_Sim[4][:,2,1], label="")
# for cellID in 2:100
#     plot!(pos_Sim[4][:,1,cellID],pos_Sim[4][:,2,cellID], label="")
# end

# display(p3)

# %%
# simNumber = 3

# p3 = plot(pos_Sim[simNumber][:,1,1],pos_Sim[simNumber][:,2,1],
# #     dpi=300,
#     label="")
# for cellID in 2:50
#     plot!(pos_Sim[simNumber][:,1,cellID],pos_Sim[simNumber][:,2,cellID], label="")
# end

# display(p3)

# # savefig(p3, "singleTrajectories_Sim"*string(simNumber)*".png")

# %%
# simNumber = 4

# p3 = plot(pos_Sim[simNumber][:,1,1],pos_Sim[simNumber][:,2,1],
# #     dpi=300,
#     label="")
# for cellID in 2:50
#     plot!(pos_Sim[simNumber][:,1,cellID],pos_Sim[simNumber][:,2,cellID], label="")
# end

# display(p3)

# # savefig(p3, "singleTrajectories_Sim"*string(simNumber)*".png")

# %%
# simNumber = 1

# p3 = plot(pos_Sim[simNumber][:,1,1],pos_Sim[simNumber][:,2,1],
# #     dpi=300,
#     label="")
# for cellID in 2:50
#     plot!(pos_Sim[simNumber][:,1,cellID],pos_Sim[simNumber][:,2,cellID], label="")
# end

# display(p3)

# # savefig(p3, "singleTrajectories_Sim"*string(simNumber)*".png")

# %%
# simNumber = 2

# p3 = plot(pos_Sim[simNumber][:,1,1],pos_Sim[simNumber][:,2,1],
# #     dpi=300,
#     label="")
# for cellID in 2:50
#     plot!(pos_Sim[simNumber][:,1,cellID],pos_Sim[simNumber][:,2,cellID], label="")
# end

# display(p3)

# # savefig(p3, "singleTrajectories_Sim"*string(simNumber)*".png")

# %%
# simNumber = 5

# p3 = plot(pos_Sim[simNumber][:,1,1],pos_Sim[simNumber][:,2,1],
# #     dpi=300,
#     label="")
# for cellID in 2:50
#     plot!(pos_Sim[simNumber][:,1,cellID],pos_Sim[simNumber][:,2,cellID], label="")
# end

# display(p3)

# # savefig(p3, "singleTrajectories_Sim"*string(simNumber)*".png")
